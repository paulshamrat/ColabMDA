# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Create a directory for GROMACS installation in Google Drive
# !mkdir -p "/content/drive/MyDrive/gmx"

# %%
# Change to the installation directory
# %cd "/content/drive/MyDrive/gmx"
# Out:
# /content/drive/MyDrive/gmx

# %%
# Print the current working directory
# %pwd
# Out:
# '/content/drive/MyDrive/gmx'

# %%
# Check GPU information
# !nvidia-smi
# Out:
# Mon Jul 14 18:25:30 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Upgrade cmake
#!pip install --upgrade cmake
# Out:
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (3.31.6)
# Collecting cmake
#   Downloading cmake-4.0.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Downloading cmake-4.0.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 79.4 MB/s eta 0:00:00
# Installing collected packages: cmake
#   Attempting uninstall: cmake
#     Found existing installation: cmake 3.31.6
#     Uninstalling cmake-3.31.6:
#       Successfully uninstalled cmake-3.31.6
# Successfully installed cmake-4.0.3

# %%
# 1. Download and install CMake 3.26
# !wget https://github.com/Kitware/CMake/releases/download/v3.26.4/cmake-3.26.4-linux-x86_64.sh
# !chmod +x cmake-3.26.4-linux-x86_64.sh
# !./cmake-3.26.4-linux-x86_64.sh --skip-license --prefix=/usr/local

# 2. Verify
# !cmake --version
# Out:
# --2025-07-14 18:28:27--  https://github.com/Kitware/CMake/releases/download/v3.26.4/cmake-3.26.4-linux-x86_64.sh
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/537699/a3e2f007-068f-4f18-a381-7db984738e8d?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-14T19%3A01%3A46Z&rscd=attachment%3B+filename%3Dcmake-3.26.4-linux-x86_64.sh&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-14T18%3A01%3A36Z&ske=2025-07-14T19%3A01%3A46Z&sks=b&skv=2018-11-09&sig=X6DyxkzThHyb76XY36zy1vcxUZulOPJ0cIJVB0%2BKSD0%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1MjUxODAwOCwibmJmIjoxNzUyNTE3NzA4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.v3lFJ5mh1uqCHlLvu-Mt186p9cWhLqjc1asdugft1Tk&response-content-disposition=attachment%3B%20filename%3Dcmake-3.26.4-linux-x86_64.sh&response-content-type=application%2Foctet-stream [following]
# --2025-07-14 18:28:28--  https://release-assets.githubusercontent.com/github-production-release-asset/537699/a3e2f007-068f-4f18-a381-7db984738e8d?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-14T19%3A01%3A46Z&rscd=attachment%3B+filename%3Dcmake-3.26.4-linux-x86_64.sh&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-14T18%3A01%3A36Z&ske=2025-07-14T19%3A01%3A46Z&sks=b&skv=2018-11-09&sig=X6DyxkzThHyb76XY36zy1vcxUZulOPJ0cIJVB0%2BKSD0%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1MjUxODAwOCwibmJmIjoxNzUyNTE3NzA4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.v3lFJ5mh1uqCHlLvu-Mt186p9cWhLqjc1asdugft1Tk&response-content-disposition=attachment%3B%20filename%3Dcmake-3.26.4-linux-x86_64.sh&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48329261 (46M) [application/octet-stream]
# Saving to: ‘cmake-3.26.4-linux-x86_64.sh.3’
#
# cmake-3.26.4-linux- 100%[===================>]  46.09M  52.1MB/s    in 0.9s
#
# 2025-07-14 18:28:29 (52.1 MB/s) - ‘cmake-3.26.4-linux-x86_64.sh.3’ saved [48329261/48329261]
#
# CMake Installer Version: 3.26.4, Copyright (c) Kitware
# This is a self-extracting archive.
# The archive will be extracted to: /usr/local
#
# Using target directory: /usr/local
# Extracting, please wait...
#
# Unpacking finished successfully
# cmake version 3.26.4
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %%
# !pwd
# Out:
# /content/drive/MyDrive/gmx

# %%
# Install dependencies
# !apt update -y
# !apt upgrade -y
# !apt install -y gcc cmake build-essential libfftw3-dev nvidia-cuda-toolkit
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,759 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,569 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,106 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,420 kB]
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,266 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,103 kB]
# Fetched 21.6 MB in 2s (9,085 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 38 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Calculating upgrade... Done
# The following packages have been kept back:
#   libcudnn9-cuda-12 libcudnn9-dev-cuda-12 libnccl-dev libnccl2
# The following packages will be upgraded:
#   base-files binutils binutils-common binutils-x86-64-linux-gnu
#   cuda-toolkit-12-config-common cuda-toolkit-config-common e2fsprogs
#   libbinutils libc-bin libcap2 libctf-nobfd0 libctf0 libext2fs2 libgnutls30
#   libldap-2.5-0 libpam-modules libpam-modules-bin libpam-runtime libpam0g
#   libperl5.34 libseccomp2 libss2 libtasn1-6 libudev1 linux-libc-dev logsave
#   openssl perl perl-base perl-modules-5.34 python3-pkg-resources r-cran-httr2
#   r-cran-rprojroot r-cran-waldo
# 34 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# Need to get 20.3 MB of archives.
# After this operation, 375 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 base-files amd64 12ubuntu4.7 [61.9 kB]
# Get:2 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-httr2 all 1.2.0-1.ca2204.1 [772 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libperl5.34 amd64 5.34.0-3ubuntu1.4 [4,820 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-12-config-common 12.9.79-1 [16.6 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-rprojroot all 2.1.0-1.ca2204.1 [109 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-waldo all 0.6.2-1.ca2204.1 [136 kB]
# Get:7 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 python3-pkg-resources all 68.1.2-2~jammy3 [216 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 perl amd64 5.34.0-3ubuntu1.4 [232 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 perl-base amd64 5.34.0-3ubuntu1.4 [1,759 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 perl-modules-5.34 all 5.34.0-3ubuntu1.4 [2,977 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-bin amd64 2.35-0ubuntu3.10 [706 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpam0g amd64 1.4.0-11ubuntu2.6 [59.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpam-modules-bin amd64 1.4.0-11ubuntu2.6 [37.4 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpam-modules amd64 1.4.0-11ubuntu2.6 [282 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 logsave amd64 1.46.5-2ubuntu1.2 [10.1 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libext2fs2 amd64 1.46.5-2ubuntu1.2 [208 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 e2fsprogs amd64 1.46.5-2ubuntu1.2 [590 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcap2 amd64 1:2.44-1ubuntu0.22.04.2 [18.3 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpam-runtime all 1.4.0-11ubuntu2.6 [40.2 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.16 [76.7 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtasn1-6 amd64 4.18.0-4ubuntu0.1 [43.5 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgnutls30 amd64 3.7.3-4ubuntu1.7 [967 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libseccomp2 amd64 2.5.3-2ubuntu3~22.04.1 [47.4 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libss2 amd64 1.46.5-2ubuntu1.2 [12.3 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openssl amd64 3.0.2-0ubuntu1.19 [1,186 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libctf0 amd64 2.38-4ubuntu2.8 [103 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libctf-nobfd0 amd64 2.38-4ubuntu2.8 [108 kB]
# Get:28 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-config-common 12.9.79-1 [16.6 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 binutils-x86-64-linux-gnu amd64 2.38-4ubuntu2.8 [2,324 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libbinutils amd64 2.38-4ubuntu2.8 [661 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 binutils amd64 2.38-4ubuntu2.8 [3,196 B]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 binutils-common amd64 2.38-4ubuntu2.8 [223 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libldap-2.5-0 amd64 2.5.19+dfsg-0ubuntu0.22.04.1 [184 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 linux-libc-dev amd64 5.15.0-143.153 [1,305 kB]
# Fetched 20.3 MB in 1s (15.6 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../base-files_12ubuntu4.7_amd64.deb ...
# Unpacking base-files (12ubuntu4.7) over (12ubuntu4.6) ...
# Setting up base-files (12ubuntu4.7) ...
# Installing new version of config file /etc/issue ...
# Installing new version of config file /etc/issue.net ...
# Installing new version of config file /etc/lsb-release ...
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../libperl5.34_5.34.0-3ubuntu1.4_amd64.deb ...
# Unpacking libperl5.34:amd64 (5.34.0-3ubuntu1.4) over (5.34.0-3ubuntu1.3) ...
# Preparing to unpack .../perl_5.34.0-3ubuntu1.4_amd64.deb ...
# Unpacking perl (5.34.0-3ubuntu1.4) over (5.34.0-3ubuntu1.3) ...
# Preparing to unpack .../perl-base_5.34.0-3ubuntu1.4_amd64.deb ...
# Unpacking perl-base (5.34.0-3ubuntu1.4) over (5.34.0-3ubuntu1.3) ...
# Setting up perl-base (5.34.0-3ubuntu1.4) ...
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../perl-modules-5.34_5.34.0-3ubuntu1.4_all.deb ...
# Unpacking perl-modules-5.34 (5.34.0-3ubuntu1.4) over (5.34.0-3ubuntu1.3) ...
# Preparing to unpack .../libc-bin_2.35-0ubuntu3.10_amd64.deb ...
# Unpacking libc-bin (2.35-0ubuntu3.10) over (2.35-0ubuntu3.8) ...
# Setting up libc-bin (2.35-0ubuntu3.10) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../libpam0g_1.4.0-11ubuntu2.6_amd64.deb ...
# Unpacking libpam0g:amd64 (1.4.0-11ubuntu2.6) over (1.4.0-11ubuntu2.4) ...
# Setting up libpam0g:amd64 (1.4.0-11ubuntu2.6) ...
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../libpam-modules-bin_1.4.0-11ubuntu2.6_amd64.deb ...
# Unpacking libpam-modules-bin (1.4.0-11ubuntu2.6) over (1.4.0-11ubuntu2.4) ...
# Setting up libpam-modules-bin (1.4.0-11ubuntu2.6) ...
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../libpam-modules_1.4.0-11ubuntu2.6_amd64.deb ...
# Unpacking libpam-modules:amd64 (1.4.0-11ubuntu2.6) over (1.4.0-11ubuntu2.4) ...
# Setting up libpam-modules:amd64 (1.4.0-11ubuntu2.6) ...
# Installing new version of config file /etc/security/namespace.init ...
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../logsave_1.46.5-2ubuntu1.2_amd64.deb ...
# Unpacking logsave (1.46.5-2ubuntu1.2) over (1.46.5-2ubuntu1.1) ...
# Preparing to unpack .../libext2fs2_1.46.5-2ubuntu1.2_amd64.deb ...
# Unpacking libext2fs2:amd64 (1.46.5-2ubuntu1.2) over (1.46.5-2ubuntu1.1) ...
# Setting up libext2fs2:amd64 (1.46.5-2ubuntu1.2) ...
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../e2fsprogs_1.46.5-2ubuntu1.2_amd64.deb ...
# Unpacking e2fsprogs (1.46.5-2ubuntu1.2) over (1.46.5-2ubuntu1.1) ...
# Preparing to unpack .../libcap2_1%3a2.44-1ubuntu0.22.04.2_amd64.deb ...
# Unpacking libcap2:amd64 (1:2.44-1ubuntu0.22.04.2) over (1:2.44-1ubuntu0.22.04.1) ...
# Setting up libcap2:amd64 (1:2.44-1ubuntu0.22.04.2) ...
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../libpam-runtime_1.4.0-11ubuntu2.6_all.deb ...
# Unpacking libpam-runtime (1.4.0-11ubuntu2.6) over (1.4.0-11ubuntu2.4) ...
# Setting up libpam-runtime (1.4.0-11ubuntu2.6) ...
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../libudev1_249.11-0ubuntu3.16_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.16) over (249.11-0ubuntu3.12) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.16) ...
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../libtasn1-6_4.18.0-4ubuntu0.1_amd64.deb ...
# Unpacking libtasn1-6:amd64 (4.18.0-4ubuntu0.1) over (4.18.0-4build1) ...
# Setting up libtasn1-6:amd64 (4.18.0-4ubuntu0.1) ...
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../libgnutls30_3.7.3-4ubuntu1.7_amd64.deb ...
# Unpacking libgnutls30:amd64 (3.7.3-4ubuntu1.7) over (3.7.3-4ubuntu1.5) ...
# Setting up libgnutls30:amd64 (3.7.3-4ubuntu1.7) ...
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../libseccomp2_2.5.3-2ubuntu3~22.04.1_amd64.deb ...
# Unpacking libseccomp2:amd64 (2.5.3-2ubuntu3~22.04.1) over (2.5.3-2ubuntu2) ...
# Setting up libseccomp2:amd64 (2.5.3-2ubuntu3~22.04.1) ...
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../00-libss2_1.46.5-2ubuntu1.2_amd64.deb ...
# Unpacking libss2:amd64 (1.46.5-2ubuntu1.2) over (1.46.5-2ubuntu1.1) ...
# Preparing to unpack .../01-openssl_3.0.2-0ubuntu1.19_amd64.deb ...
# Unpacking openssl (3.0.2-0ubuntu1.19) over (3.0.2-0ubuntu1.16) ...
# Preparing to unpack .../02-libctf0_2.38-4ubuntu2.8_amd64.deb ...
# Unpacking libctf0:amd64 (2.38-4ubuntu2.8) over (2.38-4ubuntu2.6) ...
# Preparing to unpack .../03-libctf-nobfd0_2.38-4ubuntu2.8_amd64.deb ...
# Unpacking libctf-nobfd0:amd64 (2.38-4ubuntu2.8) over (2.38-4ubuntu2.6) ...
# Preparing to unpack .../04-binutils-x86-64-linux-gnu_2.38-4ubuntu2.8_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.38-4ubuntu2.8) over (2.38-4ubuntu2.6) ...
# Preparing to unpack .../05-libbinutils_2.38-4ubuntu2.8_amd64.deb ...
# Unpacking libbinutils:amd64 (2.38-4ubuntu2.8) over (2.38-4ubuntu2.6) ...
# Preparing to unpack .../06-binutils_2.38-4ubuntu2.8_amd64.deb ...
# Unpacking binutils (2.38-4ubuntu2.8) over (2.38-4ubuntu2.6) ...
# Preparing to unpack .../07-binutils-common_2.38-4ubuntu2.8_amd64.deb ...
# Unpacking binutils-common:amd64 (2.38-4ubuntu2.8) over (2.38-4ubuntu2.6) ...
# Preparing to unpack .../08-cuda-toolkit-12-config-common_12.9.79-1_all.deb ...
# Unpacking cuda-toolkit-12-config-common (12.9.79-1) over (12.5.82-1) ...
# Preparing to unpack .../09-cuda-toolkit-config-common_12.9.79-1_all.deb ...
# Unpacking cuda-toolkit-config-common (12.9.79-1) over (12.5.82-1) ...
# Preparing to unpack .../10-libldap-2.5-0_2.5.19+dfsg-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libldap-2.5-0:amd64 (2.5.19+dfsg-0ubuntu0.22.04.1) over (2.5.17+dfsg-0ubuntu0.22.04.1) ...
# Preparing to unpack .../11-linux-libc-dev_5.15.0-143.153_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (5.15.0-143.153) over (5.15.0-113.123) ...
# Preparing to unpack .../12-python3-pkg-resources_68.1.2-2~jammy3_all.deb ...
# Unpacking python3-pkg-resources (68.1.2-2~jammy3) over (59.6.0-1.2ubuntu0.22.04.3) ...
# Preparing to unpack .../13-r-cran-httr2_1.2.0-1.ca2204.1_all.deb ...
# Unpacking r-cran-httr2 (1.2.0-1.ca2204.1) over (1.1.2-1.ca2204.1) ...
# Preparing to unpack .../14-r-cran-rprojroot_2.1.0-1.ca2204.1_all.deb ...
# Unpacking r-cran-rprojroot (2.1.0-1.ca2204.1) over (2.0.4-1.ca2204.1) ...
# Preparing to unpack .../15-r-cran-waldo_0.6.2-1.ca2204.1_all.deb ...
# Unpacking r-cran-waldo (0.6.2-1.ca2204.1) over (0.6.1-1.ca2204.1) ...
# Setting up python3-pkg-resources (68.1.2-2~jammy3) ...
# Setting up cuda-toolkit-config-common (12.9.79-1) ...
# Setting up binutils-common:amd64 (2.38-4ubuntu2.8) ...
# Setting up linux-libc-dev:amd64 (5.15.0-143.153) ...
# Setting up libctf-nobfd0:amd64 (2.38-4ubuntu2.8) ...
# Setting up perl-modules-5.34 (5.34.0-3ubuntu1.4) ...
# Setting up libldap-2.5-0:amd64 (2.5.19+dfsg-0ubuntu0.22.04.1) ...
# Setting up r-cran-rprojroot (2.1.0-1.ca2204.1) ...
# Setting up r-cran-httr2 (1.2.0-1.ca2204.1) ...
# Setting up r-cran-waldo (0.6.2-1.ca2204.1) ...
# Setting up libss2:amd64 (1.46.5-2ubuntu1.2) ...
# Setting up logsave (1.46.5-2ubuntu1.2) ...
# Setting up libbinutils:amd64 (2.38-4ubuntu2.8) ...
# Setting up openssl (3.0.2-0ubuntu1.19) ...
# Setting up cuda-toolkit-12-config-common (12.9.79-1) ...
# Setting up libctf0:amd64 (2.38-4ubuntu2.8) ...
# Setting up libperl5.34:amd64 (5.34.0-3ubuntu1.4) ...
# Setting up e2fsprogs (1.46.5-2ubuntu1.2) ...
# Setting up perl (5.34.0-3ubuntu1.4) ...
# Setting up binutils-x86-64-linux-gnu (2.38-4ubuntu2.8) ...
# Setting up binutils (2.38-4ubuntu2.8) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.10) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# gcc is already the newest version (4:11.2.0-1ubuntu1).
# gcc set to manually installed.
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libaccinj64-11.5 libatk-wrapper-java
#   libatk-wrapper-java-jni libbabeltrace1 libcub-dev libcublas11 libcublaslt11
#   libcudart11.0 libcufft10 libcufftw10 libcuinj64-11.5 libcupti-dev
#   libcupti-doc libcupti11.5 libcurand10 libcusolver11 libcusolvermg11
#   libcusparse11 libdebuginfod-common libdebuginfod1 libegl-dev libfftw3-bin
#   libfftw3-double3 libfftw3-long3 libfftw3-quad3 libfftw3-single3
#   libgail-common libgail18 libgl-dev libgl1-mesa-dev libgles-dev libgles1
#   libglvnd-core-dev libglvnd-dev libglx-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libipt2 libnppc11 libnppial11 libnppicc11 libnppidei11
#   libnppif11 libnppig11 libnppim11 libnppist11 libnppisu11 libnppitc11
#   libnpps11 libnvblas11 libnvidia-compute-495 libnvidia-compute-510
#   libnvidia-compute-535 libnvidia-ml-dev libnvjpeg11 libnvrtc-builtins11.5
#   libnvrtc11.2 libnvtoolsext1 libnvvm4 libopengl-dev librsvg2-common
#   libsource-highlight-common libsource-highlight4v5 libthrust-dev libvdpau-dev
#   libxtst6 libxxf86dga1 node-html5shiv nvidia-cuda-dev nvidia-cuda-gdb
#   nvidia-cuda-toolkit-doc nvidia-profiler nvidia-visual-profiler openjdk-8-jre
#   openjdk-8-jre-headless x11-utils
# Suggested packages:
#   libfftw3-doc gvfs libvdpau-doc nodejs libnss-mdns fonts-nanum
#   fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   fonts-wqy-zenhei fonts-indic mesa-utils
# Recommended packages:
#   libnvcuvid1 nsight-compute nsight-systems
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libaccinj64-11.5 libatk-wrapper-java
#   libatk-wrapper-java-jni libbabeltrace1 libcub-dev libcublas11 libcublaslt11
#   libcudart11.0 libcufft10 libcufftw10 libcuinj64-11.5 libcupti-dev
#   libcupti-doc libcupti11.5 libcurand10 libcusolver11 libcusolvermg11
#   libcusparse11 libdebuginfod-common libdebuginfod1 libegl-dev libfftw3-bin
#   libfftw3-dev libfftw3-double3 libfftw3-long3 libfftw3-quad3 libfftw3-single3
#   libgail-common libgail18 libgl-dev libgl1-mesa-dev libgles-dev libgles1
#   libglvnd-core-dev libglvnd-dev libglx-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libipt2 libnppc11 libnppial11 libnppicc11 libnppidei11
#   libnppif11 libnppig11 libnppim11 libnppist11 libnppisu11 libnppitc11
#   libnpps11 libnvblas11 libnvidia-compute-495 libnvidia-compute-510
#   libnvidia-compute-535 libnvidia-ml-dev libnvjpeg11 libnvrtc-builtins11.5
#   libnvrtc11.2 libnvtoolsext1 libnvvm4 libopengl-dev librsvg2-common
#   libsource-highlight-common libsource-highlight4v5 libthrust-dev libvdpau-dev
#   libxtst6 libxxf86dga1 node-html5shiv nvidia-cuda-dev nvidia-cuda-gdb
#   nvidia-cuda-toolkit nvidia-cuda-toolkit-doc nvidia-profiler
#   nvidia-visual-profiler openjdk-8-jre openjdk-8-jre-headless x11-utils
# 0 upgraded, 81 newly installed, 0 to remove and 4 not upgraded.
# Need to get 1,544 MB of archives.
# After this operation, 4,258 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdebuginfod-common all 0.186-1ubuntu0.1 [7,996 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-compute-535 535.247.01-0ubuntu1 [36.9 MB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcupti11.5 amd64 11.5.114~11.5.1-1ubuntu1 [7,696 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libaccinj64-11.5 amd64 11.5.114~11.5.1-1ubuntu1 [845 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcub-dev all 1.15.0-3 [217 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcublaslt11 amd64 11.7.4.6~11.5.1-1ubuntu1 [148 MB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcublas11 amd64 11.7.4.6~11.5.1-1ubuntu1 [78.2 MB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcudart11.0 amd64 11.5.117~11.5.1-1ubuntu1 [178 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcufft10 amd64 11.1.1+~10.6.0.107~11.5.1-1ubuntu1 [70.4 MB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcufftw10 amd64 11.1.1+~10.6.0.107~11.5.1-1ubuntu1 [211 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 libnvidia-compute-510 amd64 525.147.05-0ubuntu2.22.04.1 [7,310 B]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 libnvidia-compute-495 amd64 510.108.03-0ubuntu0.22.04.1 [7,378 B]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcuinj64-11.5 amd64 11.5.114~11.5.1-1ubuntu1 [1,004 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcurand10 amd64 11.1.1+~10.2.7.107~11.5.1-1ubuntu1 [41.8 MB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcusolver11 amd64 11.3.2.107~11.5.1-1ubuntu1 [31.3 MB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcusolvermg11 amd64 11.3.2.107~11.5.1-1ubuntu1 [17.8 MB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcusparse11 amd64 11.7.0.107~11.5.1-1ubuntu1 [96.2 MB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdebuginfod1 amd64 0.186-1ubuntu0.1 [12.8 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-double3 amd64 3.3.8-2ubuntu8 [770 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-long3 amd64 3.3.8-2ubuntu8 [335 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-quad3 amd64 3.3.8-2ubuntu8 [614 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-single3 amd64 3.3.8-2ubuntu8 [800 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-bin amd64 3.3.8-2ubuntu8 [35.5 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-dev amd64 3.3.8-2ubuntu8 [2,101 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail18 amd64 2.24.33-2ubuntu2.1 [15.9 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail-common amd64 2.24.33-2ubuntu2.1 [132 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2.1 [7,936 B]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libipt2 amd64 2.0.5-1 [46.4 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppc11 amd64 11.5.1.107~11.5.1-1ubuntu1 [430 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppial11 amd64 11.5.1.107~11.5.1-1ubuntu1 [5,234 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppicc11 amd64 11.5.1.107~11.5.1-1ubuntu1 [2,373 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppidei11 amd64 11.5.1.107~11.5.1-1ubuntu1 [2,587 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppif11 amd64 11.5.1.107~11.5.1-1ubuntu1 [33.8 MB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppig11 amd64 11.5.1.107~11.5.1-1ubuntu1 [14.5 MB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppim11 amd64 11.5.1.107~11.5.1-1ubuntu1 [3,037 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppist11 amd64 11.5.1.107~11.5.1-1ubuntu1 [13.7 MB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppisu11 amd64 11.5.1.107~11.5.1-1ubuntu1 [177 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppitc11 amd64 11.5.1.107~11.5.1-1ubuntu1 [1,292 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnpps11 amd64 11.5.1.107~11.5.1-1ubuntu1 [7,116 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvblas11 amd64 11.7.4.6~11.5.1-1ubuntu1 [191 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvidia-ml-dev amd64 11.5.50~11.5.1-1ubuntu1 [69.1 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvjpeg11 amd64 11.5.4.107~11.5.1-1ubuntu1 [1,858 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvrtc-builtins11.5 amd64 11.5.119~11.5.1-1ubuntu1 [116 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvrtc11.2 amd64 11.5.119~11.5.1-1ubuntu1 [15.7 MB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvvm4 amd64 11.5.119~11.5.1-1ubuntu1 [8,675 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:61 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsource-highlight-common all 3.1.9-4.1build2 [64.5 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsource-highlight4v5 amd64 3.1.9-4.1build2 [207 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvdpau-dev amd64 1.4-3build2 [38.7 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 node-html5shiv all 3.7.3+dfsg-4 [13.6 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-toolkit-doc all 11.5.1-1ubuntu1 [6,263 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-8-jre-headless amd64 8u452-ga~us1-0ubuntu1~22.04 [30.8 MB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-8-jre amd64 8u452-ga~us1-0ubuntu1~22.04 [75.3 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 libbabeltrace1 amd64 1.5.8-2build1 [160 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcupti-dev amd64 11.5.114~11.5.1-1ubuntu1 [7,915 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcupti-doc all 11.5.114~11.5.1-1ubuntu1 [2,373 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:74 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [6,848 B]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvtoolsext1 amd64 11.5.114~11.5.1-1ubuntu1 [28.8 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libthrust-dev all 1.15.0-1 [423 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-dev amd64 11.5.1-1ubuntu1 [667 MB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-gdb amd64 11.5.114~11.5.1-1ubuntu1 [3,404 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-profiler amd64 11.5.114~11.5.1-1ubuntu1 [1,732 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-toolkit amd64 11.5.1-1ubuntu1 [62.8 MB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-visual-profiler amd64 11.5.114~11.5.1-1ubuntu1 [108 MB]
# Fetched 1,544 MB in 1min 25s (18.1 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package libdebuginfod-common.
# (Reading database ... 126307 files and directories currently installed.)
# Preparing to unpack .../00-libdebuginfod-common_0.186-1ubuntu0.1_all.deb ...
# Unpacking libdebuginfod-common (0.186-1ubuntu0.1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../01-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../02-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libcupti11.5:amd64.
# Preparing to unpack .../03-libcupti11.5_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcupti11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libaccinj64-11.5:amd64.
# Preparing to unpack .../04-libaccinj64-11.5_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libaccinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../05-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../06-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../07-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../08-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../09-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libcub-dev.
# Preparing to unpack .../10-libcub-dev_1.15.0-3_all.deb ...
# Unpacking libcub-dev (1.15.0-3) ...
# Selecting previously unselected package libcublaslt11:amd64.
# Preparing to unpack .../11-libcublaslt11_11.7.4.6~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcublaslt11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcublas11:amd64.
# Preparing to unpack .../12-libcublas11_11.7.4.6~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcublas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcudart11.0:amd64.
# Preparing to unpack .../13-libcudart11.0_11.5.117~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcudart11.0:amd64 (11.5.117~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcufft10:amd64.
# Preparing to unpack .../14-libcufft10_11.1.1+~10.6.0.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcufft10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcufftw10:amd64.
# Preparing to unpack .../15-libcufftw10_11.1.1+~10.6.0.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcufftw10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-535:amd64.
# Preparing to unpack .../16-libnvidia-compute-535_535.247.01-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-535:amd64 (535.247.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-510:amd64.
# Preparing to unpack .../17-libnvidia-compute-510_525.147.05-0ubuntu2.22.04.1_amd64.deb ...
# Unpacking libnvidia-compute-510:amd64 (525.147.05-0ubuntu2.22.04.1) ...
# Selecting previously unselected package libnvidia-compute-495:amd64.
# Preparing to unpack .../18-libnvidia-compute-495_510.108.03-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libnvidia-compute-495:amd64 (510.108.03-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libcuinj64-11.5:amd64.
# Preparing to unpack .../19-libcuinj64-11.5_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcuinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcurand10:amd64.
# Preparing to unpack .../20-libcurand10_11.1.1+~10.2.7.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcurand10:amd64 (11.1.1+~10.2.7.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcusolver11:amd64.
# Preparing to unpack .../21-libcusolver11_11.3.2.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcusolver11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcusolvermg11:amd64.
# Preparing to unpack .../22-libcusolvermg11_11.3.2.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcusolvermg11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcusparse11:amd64.
# Preparing to unpack .../23-libcusparse11_11.7.0.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcusparse11:amd64 (11.7.0.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libdebuginfod1:amd64.
# Preparing to unpack .../24-libdebuginfod1_0.186-1ubuntu0.1_amd64.deb ...
# Unpacking libdebuginfod1:amd64 (0.186-1ubuntu0.1) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../25-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../26-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../27-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libfftw3-double3:amd64.
# Preparing to unpack .../28-libfftw3-double3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-long3:amd64.
# Preparing to unpack .../29-libfftw3-long3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-long3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-quad3:amd64.
# Preparing to unpack .../30-libfftw3-quad3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-quad3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-single3:amd64.
# Preparing to unpack .../31-libfftw3-single3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-single3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-bin.
# Preparing to unpack .../32-libfftw3-bin_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-bin (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-dev:amd64.
# Preparing to unpack .../33-libfftw3-dev_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-dev:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../34-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../35-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../36-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../37-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../38-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../39-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../40-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libipt2.
# Preparing to unpack .../41-libipt2_2.0.5-1_amd64.deb ...
# Unpacking libipt2 (2.0.5-1) ...
# Selecting previously unselected package libnppc11:amd64.
# Preparing to unpack .../42-libnppc11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppial11:amd64.
# Preparing to unpack .../43-libnppial11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppial11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppicc11:amd64.
# Preparing to unpack .../44-libnppicc11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppicc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppidei11:amd64.
# Preparing to unpack .../45-libnppidei11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppidei11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppif11:amd64.
# Preparing to unpack .../46-libnppif11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppif11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppig11:amd64.
# Preparing to unpack .../47-libnppig11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppig11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppim11:amd64.
# Preparing to unpack .../48-libnppim11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppim11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppist11:amd64.
# Preparing to unpack .../49-libnppist11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppist11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppisu11:amd64.
# Preparing to unpack .../50-libnppisu11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppisu11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppitc11:amd64.
# Preparing to unpack .../51-libnppitc11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppitc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnpps11:amd64.
# Preparing to unpack .../52-libnpps11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnpps11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvblas11:amd64.
# Preparing to unpack .../53-libnvblas11_11.7.4.6~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvblas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvidia-ml-dev:amd64.
# Preparing to unpack .../54-libnvidia-ml-dev_11.5.50~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvidia-ml-dev:amd64 (11.5.50~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvjpeg11:amd64.
# Preparing to unpack .../55-libnvjpeg11_11.5.4.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvjpeg11:amd64 (11.5.4.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvrtc-builtins11.5:amd64.
# Preparing to unpack .../56-libnvrtc-builtins11.5_11.5.119~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvrtc-builtins11.5:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvrtc11.2:amd64.
# Preparing to unpack .../57-libnvrtc11.2_11.5.119~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvrtc11.2:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvvm4:amd64.
# Preparing to unpack .../58-libnvvm4_11.5.119~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvvm4:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../59-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../60-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libsource-highlight-common.
# Preparing to unpack .../61-libsource-highlight-common_3.1.9-4.1build2_all.deb ...
# Unpacking libsource-highlight-common (3.1.9-4.1build2) ...
# Selecting previously unselected package libsource-highlight4v5.
# Preparing to unpack .../62-libsource-highlight4v5_3.1.9-4.1build2_amd64.deb ...
# Unpacking libsource-highlight4v5 (3.1.9-4.1build2) ...
# Selecting previously unselected package libvdpau-dev:amd64.
# Preparing to unpack .../63-libvdpau-dev_1.4-3build2_amd64.deb ...
# Unpacking libvdpau-dev:amd64 (1.4-3build2) ...
# Selecting previously unselected package node-html5shiv.
# Preparing to unpack .../64-node-html5shiv_3.7.3+dfsg-4_all.deb ...
# Unpacking node-html5shiv (3.7.3+dfsg-4) ...
# Selecting previously unselected package nvidia-cuda-toolkit-doc.
# Preparing to unpack .../65-nvidia-cuda-toolkit-doc_11.5.1-1ubuntu1_all.deb ...
# Unpacking nvidia-cuda-toolkit-doc (11.5.1-1ubuntu1) ...
# Selecting previously unselected package openjdk-8-jre-headless:amd64.
# Preparing to unpack .../66-openjdk-8-jre-headless_8u452-ga~us1-0ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u452-ga~us1-0ubuntu1~22.04) ...
# Selecting previously unselected package openjdk-8-jre:amd64.
# Preparing to unpack .../67-openjdk-8-jre_8u452-ga~us1-0ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-8-jre:amd64 (8u452-ga~us1-0ubuntu1~22.04) ...
# Selecting previously unselected package libbabeltrace1:amd64.
# Preparing to unpack .../68-libbabeltrace1_1.5.8-2build1_amd64.deb ...
# Unpacking libbabeltrace1:amd64 (1.5.8-2build1) ...
# Selecting previously unselected package libcupti-dev:amd64.
# Preparing to unpack .../69-libcupti-dev_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcupti-dev:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcupti-doc.
# Preparing to unpack .../70-libcupti-doc_11.5.114~11.5.1-1ubuntu1_all.deb ...
# Unpacking libcupti-doc (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../71-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../72-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../73-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libnvtoolsext1:amd64.
# Preparing to unpack .../74-libnvtoolsext1_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvtoolsext1:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libthrust-dev.
# Preparing to unpack .../75-libthrust-dev_1.15.0-1_all.deb ...
# Unpacking libthrust-dev (1.15.0-1) ...
# Selecting previously unselected package nvidia-cuda-dev:amd64.
# Preparing to unpack .../76-nvidia-cuda-dev_11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-dev:amd64 (11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-cuda-gdb.
# Preparing to unpack .../77-nvidia-cuda-gdb_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-gdb (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-profiler.
# Preparing to unpack .../78-nvidia-profiler_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-cuda-toolkit.
# Preparing to unpack .../79-nvidia-cuda-toolkit_11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-toolkit (11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-visual-profiler.
# Preparing to unpack .../80-nvidia-visual-profiler_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-visual-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libfftw3-single3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libcusparse11:amd64 (11.7.0.107~11.5.1-1ubuntu1) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libdebuginfod-common (0.186-1ubuntu0.1) ...
#
# Creating config file /etc/profile.d/debuginfod.sh with new version
#
# Creating config file /etc/profile.d/debuginfod.csh with new version
# Setting up libnppc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libdebuginfod1:amd64 (0.186-1ubuntu0.1) ...
# Setting up node-html5shiv (3.7.3+dfsg-4) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libcupti-doc (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libfftw3-long3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libsource-highlight-common (3.1.9-4.1build2) ...
# Setting up libcudart11.0:amd64 (11.5.117~11.5.1-1ubuntu1) ...
# Setting up libnppisu11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppicc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnvjpeg11:amd64 (11.5.4.107~11.5.1-1ubuntu1) ...
# Setting up libcublaslt11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up libfftw3-quad3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libcupti11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up openjdk-8-jre-headless:amd64 (8u452-ga~us1-0ubuntu1~22.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/orbd to provide /usr/bin/orbd (orbd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/servertool to provide /usr/bin/servertool (servertool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/tnameserv to provide /usr/bin/tnameserv (tnameserv) in auto mode
# Setting up libipt2 (2.0.5-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libbabeltrace1:amd64 (1.5.8-2build1) ...
# Setting up libnpps11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppim11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libcufft10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libnppitc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppist11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libnvidia-compute-535:amd64 (535.247.01-0ubuntu1) ...
# Setting up libnvvm4:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Setting up libvdpau-dev:amd64 (1.4-3build2) ...
# Setting up libnvtoolsext1:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libcub-dev (1.15.0-3) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up nvidia-cuda-toolkit-doc (11.5.1-1ubuntu1) ...
# Setting up libaccinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libnppig11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libcurand10:amd64 (11.1.1+~10.2.7.107~11.5.1-1ubuntu1) ...
# Setting up libsource-highlight4v5 (3.1.9-4.1build2) ...
# Setting up libnvrtc-builtins11.5:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Setting up libnppidei11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libthrust-dev (1.15.0-1) ...
# Setting up libnppial11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppif11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libcufftw10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Setting up libcublas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Setting up nvidia-cuda-gdb (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up libfftw3-bin (3.3.8-2ubuntu8) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libnvidia-compute-510:amd64 (525.147.05-0ubuntu2.22.04.1) ...
# Setting up libcupti-dev:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libnvidia-compute-495:amd64 (510.108.03-0ubuntu0.22.04.1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up libnvblas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Setting up libcusolver11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Setting up libnvrtc11.2:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Setting up libcusolvermg11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up libfftw3-dev:amd64 (3.3.8-2ubuntu8) ...
# Setting up libcuinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libnvidia-ml-dev:amd64 (11.5.50~11.5.1-1ubuntu1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up nvidia-cuda-dev:amd64 (11.5.1-1ubuntu1) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up openjdk-8-jre:amd64 (8u452-ga~us1-0ubuntu1~22.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/policytool to provide /usr/bin/policytool (policytool) in auto mode
# Setting up nvidia-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Setting up nvidia-cuda-toolkit (11.5.1-1ubuntu1) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up nvidia-visual-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.10) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...

# %%
# Download and install hwloc
# !wget https://download.open-mpi.org/release/hwloc/v1.11/hwloc-1.11.13.tar.gz
# !tar xzf hwloc-1.11.13.tar.gz
# %cd hwloc-1.11.13
# !./configure
# !make
# !sudo make install
# %cd ..
# Out:
# --2025-07-14 18:32:03--  https://download.open-mpi.org/release/hwloc/v1.11/hwloc-1.11.13.tar.gz
# Resolving download.open-mpi.org (download.open-mpi.org)... 3.168.147.13, 3.168.147.84, 3.168.147.75, ...
# Connecting to download.open-mpi.org (download.open-mpi.org)|3.168.147.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4487770 (4.3M) [binary/octet-stream]
# Saving to: ‘hwloc-1.11.13.tar.gz’
#
# hwloc-1.11.13.tar.g 100%[===================>]   4.28M  23.0MB/s    in 0.2s
#
# 2025-07-14 18:32:03 (23.0 MB/s) - ‘hwloc-1.11.13.tar.gz’ saved [4487770/4487770]
#
# /content/drive/MyDrive/gmx/hwloc-1.11.13
#
# ###
# ### Configuring hwloc distribution tarball
# ### Startup tests
# ###
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking target system type... x86_64-unknown-linux-gnu
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking whether UID '0' is supported by ustar format... yes
# checking whether GID '0' is supported by ustar format... yes
# checking how to create a ustar tar archive... gnutar
# checking whether make supports nested variables... (cached) yes
# checking for style of include used by make... GNU
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking whether gcc understands -c and -o together... yes
# checking dependency style of gcc... gcc3
# checking how to run the C preprocessor... gcc -E
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking minix/config.h usability... no
# checking minix/config.h presence... no
# checking for minix/config.h... no
# checking whether it is safe to define __EXTENSIONS__... yes
# checking for gcc... (cached) gcc
# checking whether we are using the GNU C compiler... (cached) yes
# checking whether gcc accepts -g... (cached) yes
# checking for gcc option to accept ISO C89... (cached) none needed
# checking whether gcc understands -c and -o together... (cached) yes
# checking dependency style of gcc... (cached) gcc3
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking dependency style of g++... gcc3
# checking for ar... ar
# checking the archiver (ar) interface... ar
# checking for pkg-config... /usr/bin/pkg-config
# checking pkg-config is at least version 0.9.0... yes
# checking for X... libraries , headers
#
# ###
# ### Configuring hwloc core
# ###
# checking hwloc building mode... standalone
# configure: hwloc builddir: /content/drive/MyDrive/gmx/hwloc-1.11.13
# configure: hwloc srcdir: /content/drive/MyDrive/gmx/hwloc-1.11.13
# checking for hwloc version... 1.11.13
# checking if want hwloc maintainer support... disabled
# checking for hwloc directory prefix... (none)
# checking for hwloc symbol prefix... hwloc_
# checking size of void *... 8
# checking which OS support to include... Linux
# checking which CPU support to include... x86_64
# checking size of unsigned long... 8
# checking size of unsigned int... 4
# checking for the C compiler vendor... gnu
# checking for __attribute__... yes
# checking for __attribute__(aligned)... yes
# checking for __attribute__(always_inline)... yes
# checking for __attribute__(cold)... yes
# checking for __attribute__(const)... yes
# checking for __attribute__(deprecated)... yes
# checking for __attribute__(format)... yes
# checking for __attribute__(hot)... yes
# checking for __attribute__(malloc)... yes
# checking for __attribute__(may_alias)... yes
# checking for __attribute__(no_instrument_function)... yes
# checking for __attribute__(nonnull)... yes
# checking for __attribute__(noreturn)... yes
# checking for __attribute__(packed)... yes
# checking for __attribute__(pure)... yes
# checking for __attribute__(sentinel)... yes
# checking for __attribute__(unused)... yes
# checking for __attribute__(warn_unused_result)... yes
# checking for __attribute__(weak_alias)... yes
# checking if gcc supports -fvisibility=hidden... yes
# checking whether to enable symbol visibility... yes (via -fvisibility=hidden)
# configure: WARNING: "-fvisibility=hidden" has been added to the hwloc CFLAGS
# checking whether the C compiler rejects function calls with too many arguments... yes
# checking whether the C compiler rejects function calls with too few arguments... yes
# checking for unistd.h... (cached) yes
# checking dirent.h usability... yes
# checking dirent.h presence... yes
# checking for dirent.h... yes
# checking for strings.h... (cached) yes
# checking ctype.h usability... yes
# checking ctype.h presence... yes
# checking for ctype.h... yes
# checking for strcasecmp... yes
# checking whether strcasecmp is declared... yes
# checking whether function strcasecmp has a complete prototype... yes
# checking for strncasecmp... yes
# checking whether strncasecmp is declared... yes
# checking whether function strncasecmp has a complete prototype... yes
# checking for strftime... yes
# checking for setlocale... yes
# checking for stdint.h... (cached) yes
# checking sys/mman.h usability... yes
# checking sys/mman.h presence... yes
# checking for sys/mman.h... yes
# checking for KAFFINITY... no
# checking for PROCESSOR_CACHE_TYPE... no
# checking for CACHE_DESCRIPTOR... no
# checking for LOGICAL_PROCESSOR_RELATIONSHIP... no
# checking for RelationProcessorPackage... no
# checking for SYSTEM_LOGICAL_PROCESSOR_INFORMATION... no
# checking for GROUP_AFFINITY... no
# checking for PROCESSOR_RELATIONSHIP... no
# checking for NUMA_NODE_RELATIONSHIP... no
# checking for CACHE_RELATIONSHIP... no
# checking for PROCESSOR_GROUP_INFO... no
# checking for GROUP_RELATIONSHIP... no
# checking for SYSTEM_LOGICAL_PROCESSOR_INFORMATION_EX... no
# checking for PSAPI_WORKING_SET_EX_BLOCK... no
# checking for PSAPI_WORKING_SET_EX_INFORMATION... no
# checking for PROCESSOR_NUMBER... no
# checking for main in -lgdi32... no
# checking for PostQuitMessage in -luser32... no
# checking windows.h usability... no
# checking windows.h presence... no
# checking for windows.h... no
# checking sys/lgrp_user.h usability... no
# checking sys/lgrp_user.h presence... no
# checking for sys/lgrp_user.h... no
# checking kstat.h usability... no
# checking kstat.h presence... no
# checking for kstat.h... no
# checking whether fabsf is declared... yes
# checking for fabsf in -lm... yes
# checking whether modff is declared... yes
# checking for modff in -lm... yes
# checking picl.h usability... no
# checking picl.h presence... no
# checking for picl.h... no
# checking whether _SC_NPROCESSORS_ONLN is declared... yes
# checking whether _SC_NPROCESSORS_CONF is declared... yes
# checking whether _SC_NPROC_ONLN is declared... no
# checking whether _SC_NPROC_CONF is declared... no
# checking whether _SC_PAGESIZE is declared... yes
# checking whether _SC_PAGE_SIZE is declared... yes
# checking whether _SC_LARGE_PAGESIZE is declared... no
# checking mach/mach_host.h usability... no
# checking mach/mach_host.h presence... no
# checking for mach/mach_host.h... no
# checking mach/mach_init.h usability... no
# checking mach/mach_init.h presence... no
# checking for mach/mach_init.h... no
# checking sys/param.h usability... yes
# checking sys/param.h presence... yes
# checking for sys/param.h... yes
# checking for sys/sysctl.h... no
# checking whether strtoull is declared... yes
# checking for ssize_t... yes
# checking whether snprintf is declared... yes
# checking whether _strdup is declared... no
# checking whether _putenv is declared... no
# checking whether getprogname is declared... no
# checking whether getexecname is declared... no
# checking whether GetModuleFileName is declared... no
# checking for program_invocation_name... yes
# checking for __progname... yes
# checking for pthread_t... yes
# checking whether sched_getcpu is declared... yes
# checking whether sched_setaffinity is declared... yes
# checking whether function sched_setaffinity has a complete prototype... yes
# checking for old prototype of sched_setaffinity... no
# checking for working CPU_SET... yes
# checking for working CPU_SET_S... yes
# checking for working syscall... yes
# checking for KERRIGHED... no
# checking for lib... no
# checking for bash... /bin/bash
# checking for ffs... yes
# checking whether ffs is declared... yes
# checking whether function ffs has a complete prototype... yes
# checking for ffsl... yes
# checking whether ffsl is declared... yes
# checking whether function ffsl has a complete prototype... yes
# checking for fls... no
# checking for flsl... no
# checking for clz... no
# checking for clzl... no
# checking for openat... yes
# checking malloc.h usability... yes
# checking malloc.h presence... yes
# checking for malloc.h... yes
# checking for getpagesize... yes
# checking for memalign... yes
# checking for posix_memalign... yes
# checking sys/utsname.h usability... yes
# checking sys/utsname.h presence... yes
# checking for sys/utsname.h... yes
# checking for uname... yes
# checking valgrind/valgrind.h usability... no
# checking valgrind/valgrind.h presence... no
# checking for valgrind/valgrind.h... no
# checking whether RUNNING_ON_VALGRIND is declared... no
# checking pthread_np.h usability... no
# checking pthread_np.h presence... no
# checking for pthread_np.h... no
# checking whether pthread_setaffinity_np is declared... yes
# checking whether pthread_getaffinity_np is declared... yes
# checking for sched_setaffinity... yes
# checking for sys/cpuset.h... no
# checking for cpuset_setaffinity... no
# checking for library containing pthread_getthrds_np... no
# checking for cpuset_setid... no
# checking numaif.h usability... yes
# checking numaif.h presence... yes
# checking for numaif.h... yes
# checking for numa_available in -lnuma... yes
# checking for set_mempolicy in -lnuma... yes
# checking for mbind in -lnuma... yes
# checking for migrate_pages in -lnuma... yes
# checking for move_pages in -lnuma... yes
# checking libudev.h usability... no
# checking libudev.h presence... no
# checking for libudev.h... no
# checking for PCIACCESS... no
# checking pciaccess.h usability... no
# checking pciaccess.h presence... no
# checking for pciaccess.h... no
# checking CL/cl_ext.h usability... yes
# checking CL/cl_ext.h presence... yes
# checking for CL/cl_ext.h... yes
# checking for clGetDeviceIDs in -lOpenCL... yes
# checking whether CL_DEVICE_TOPOLOGY_AMD is declared... yes
# checking cuda.h usability... yes
# checking cuda.h presence... yes
# checking for cuda.h... yes
# checking if CUDA_VERSION >= 3020... yes
# checking for cuInit in -lcuda... yes
# checking cuda_runtime_api.h usability... yes
# checking cuda_runtime_api.h presence... yes
# checking for cuda_runtime_api.h... yes
# checking if CUDART_VERSION >= 3020... yes
# checking for cudaGetDeviceProperties in -lcudart... yes
# checking nvml.h usability... yes
# checking nvml.h presence... yes
# checking for nvml.h... yes
# checking for nvmlInit in -lnvidia-ml... yes
# checking whether nvmlDeviceGetMaxPcieLinkGeneration is declared... yes
# checking for gethostbyname... yes
# checking for connect... yes
# checking for remove... yes
# checking for shmat... yes
# checking for IceConnectionNumber in -lICE... yes
# checking X11/Xlib.h usability... yes
# checking X11/Xlib.h presence... yes
# checking for X11/Xlib.h... yes
# checking for XOpenDisplay in -lX11... yes
# checking for X11/Xutil.h... yes
# checking X11/keysym.h usability... yes
# checking X11/keysym.h presence... yes
# checking for X11/keysym.h... yes
# checking NVCtrl/NVCtrl.h usability... no
# checking NVCtrl/NVCtrl.h presence... no
# checking for NVCtrl/NVCtrl.h... no
# checking for LIBXML2... yes
# checking libxml/parser.h usability... yes
# checking libxml/parser.h presence... yes
# checking for libxml/parser.h... yes
# checking for xmlNewDoc... yes
# checking for final LIBXML2 support... yes
# checking for x86 cpuid... yes
# checking for pthread_mutex_lock... yes
# checking if plugin support is enabled... no
# checking components to build statically...  noos xml synthetic custom xml_nolibxml linux linuxpci opencl cuda nvml xml_libxml x86
# checking components to build as plugins...
# checking for a sed that does not truncate output... /usr/bin/sed
#
# ###
# ### Configuring hwloc documentation
# ###
# checking if this is a developer build... no (doxygen generation is optional)
# checking for doxygen... no
# checking for pdflatex... no
# checking for makeindex... no
# checking for fig2dev... no
# checking for gs... no
# checking for epstopdf... no
# checking if can build doxygen docs... no
# checking for w3m... no
# checking for lynx... no
# checking if can build top-level README... no
# checking if will build doxygen docs... no
# checking if will install doxygen docs... yes
# checking whether to enable "picky" compiler mode... no (default)
#
# ###
# ### Configuring hwloc command line utilities
# ###
# checking for CAIRO... yes
# checking cairo.h usability... yes
# checking cairo.h presence... yes
# checking for cairo.h... yes
# checking for cairo_fill... yes
# checking for final CAIRO support... yes
# checking for wchar_t... yes
# checking for putwc... yes
# checking locale.h usability... yes
# checking locale.h presence... yes
# checking for locale.h... yes
# checking for setlocale... (cached) yes
# checking for uselocale... yes
# checking xlocale.h usability... no
# checking xlocale.h presence... no
# checking for xlocale.h... no
# checking langinfo.h usability... yes
# checking langinfo.h presence... yes
# checking for langinfo.h... yes
# checking for nl_langinfo... yes
# checking termcap support using ncurses and ... no
# checking termcap support using ncurses and -ltermcap... yes
# checking whether diff accepts -u... yes
# checking whether diff accepts -w... yes
# checking time.h usability... yes
# checking time.h presence... yes
# checking for time.h... yes
# checking for clock_gettime... yes
#
# ###
# ### Configuring hwloc tests
# ###
# checking for pthread_self in -lpthread... yes
# checking for numa_available in -lnuma... (cached) yes
# checking whether numa_bitmask_alloc is declared... yes
# checking for stdlib.h... (cached) yes
# checking for mkstemp... yes
# checking infiniband/verbs.h usability... yes
# checking infiniband/verbs.h presence... yes
# checking for infiniband/verbs.h... yes
# checking for ibv_open_device in -libverbs... yes
# checking myriexpress.h usability... no
# checking myriexpress.h presence... no
# checking for myriexpress.h... no
# checking for xmllint... no
# checking for bunzip2... bunzip2
# checking if CXX works... yes
# checking whether diff accepts -u... yes
#
# ###
# ### Performing final hwloc configuration
# ###
# checking how to print strings... printf
# checking for a sed that does not truncate output... (cached) /usr/bin/sed
# checking for fgrep... /usr/bin/grep -F
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking whether ln -s works... yes
# checking the maximum length of command line arguments... 1572864
# checking how to convert x86_64-unknown-linux-gnu file names to x86_64-unknown-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-unknown-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... no
# checking how to associate runtime and link libraries... printf %s\n
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking command to parse /usr/bin/nm -B output from gcc object... ok
# checking for sysroot... no
# checking for a working dd... /usr/bin/dd
# checking how to truncate binary pipes... /usr/bin/dd bs=4096 count=1
# checking for mt... no
# checking if : is a manifest tool... no
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if gcc supports -fno-rtti -fno-exceptions... no
# checking for gcc option to produce PIC... -fPIC -DPIC
# checking if gcc PIC flag -fPIC -DPIC works... yes
# checking if gcc static flag -static works... yes
# checking if gcc supports -c -o file.o... yes
# checking if gcc supports -c -o file.o... (cached) yes
# checking whether the gcc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking for shl_load... no
# checking for shl_load in -ldld... no
# checking for dlopen... yes
# checking whether a program can dlopen itself... yes
# checking whether a statically linked program can dlopen itself... no
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... no
# checking how to run the C++ preprocessor... g++ -E
# checking for ld used by g++... /usr/bin/ld -m elf_x86_64
# checking if the linker (/usr/bin/ld -m elf_x86_64) is GNU ld... yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking for g++ option to produce PIC... -fPIC -DPIC
# checking if g++ PIC flag -fPIC -DPIC works... yes
# checking if g++ static flag -static works... yes
# checking if g++ supports -c -o file.o... yes
# checking if g++ supports -c -o file.o... (cached) yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking dynamic linker characteristics... (cached) GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating include/Makefile
# config.status: creating src/Makefile
# config.status: creating doc/Makefile
# config.status: creating doc/examples/Makefile
# config.status: creating doc/doxygen-config.cfg
# config.status: creating utils/Makefile
# config.status: creating utils/hwloc/Makefile
# config.status: creating utils/lstopo/Makefile
# config.status: creating hwloc.pc
# config.status: creating tests/Makefile
# config.status: creating tests/linux/Makefile
# config.status: creating tests/linux/allowed/Makefile
# config.status: creating tests/linux/gather/Makefile
# config.status: creating tests/xml/Makefile
# config.status: creating tests/ports/Makefile
# config.status: creating tests/rename/Makefile
# config.status: creating tests/linux/allowed/test-topology.sh
# config.status: creating tests/linux/gather/test-gather-topology.sh
# config.status: creating tests/linux/test-topology.sh
# config.status: creating tests/xml/test-topology.sh
# config.status: creating tests/wrapper.sh
# config.status: creating utils/hwloc/hwloc-assembler-remote
# config.status: creating utils/hwloc/hwloc-compress-dir
# config.status: creating utils/hwloc/hwloc-gather-topology
# config.status: creating utils/hwloc/test-hwloc-annotate.sh
# config.status: creating utils/hwloc/test-hwloc-assembler.sh
# config.status: creating utils/hwloc/test-hwloc-calc.sh
# config.status: creating utils/hwloc/test-hwloc-compress-dir.sh
# config.status: creating utils/hwloc/test-hwloc-diffpatch.sh
# config.status: creating utils/hwloc/test-hwloc-distances.sh
# config.status: creating utils/hwloc/test-hwloc-distrib.sh
# config.status: creating utils/hwloc/test-hwloc-info.sh
# config.status: creating utils/hwloc/test-fake-plugin.sh
# config.status: creating utils/lstopo/test-hwloc-ls.sh
# config.status: creating contrib/systemd/Makefile
# config.status: creating include/private/autogen/config.h
# config.status: creating include/hwloc/autogen/config.h
# config.status: linking src/topology-solaris.c to tests/ports/topology-solaris.c
# config.status: linking src/topology-solaris-chiptype.c to tests/ports/topology-solaris-chiptype.c
# config.status: linking src/topology-aix.c to tests/ports/topology-aix.c
# config.status: linking src/topology-osf.c to tests/ports/topology-osf.c
# config.status: linking src/topology-windows.c to tests/ports/topology-windows.c
# config.status: linking src/topology-darwin.c to tests/ports/topology-darwin.c
# config.status: linking src/topology-freebsd.c to tests/ports/topology-freebsd.c
# config.status: linking src/topology-netbsd.c to tests/ports/topology-netbsd.c
# config.status: linking src/topology-hpux.c to tests/ports/topology-hpux.c
# config.status: linking src/topology-bgq.c to tests/ports/topology-bgq.c
# config.status: linking src/topology-opencl.c to tests/ports/topology-opencl.c
# config.status: linking src/topology-cuda.c to tests/ports/topology-cuda.c
# config.status: linking src/topology-nvml.c to tests/ports/topology-nvml.c
# config.status: linking src/topology-gl.c to tests/ports/topology-gl.c
# config.status: executing depfiles commands
# config.status: executing chmoding-scripts commands
# config.status: executing libtool commands
#
# -----------------------------------------------------------------------------
# Hwloc optional build support status (more details can be found above):
#
# Probe / display I/O devices: PCI(linux) OpenCL CUDA NVML
# Graphical output (Cairo):    yes
# XML input / output:          full
# libnuma memory support:      yes
# Plugin support:              no
# -----------------------------------------------------------------------------
#
# Making all in src
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/src'
#   CC       topology.lo
#   CC       traversal.lo
#   CC       distances.lo
#   CC       components.lo
#   CC       bind.lo
#   CC       bitmap.lo
#   CC       pci-common.lo
#   CC       diff.lo
#   CC       misc.lo
#   CC       base64.lo
#   CC       topology-noos.lo
#   CC       topology-synthetic.lo
#   CC       topology-custom.lo
#   CC       topology-xml.lo
#   CC       topology-xml-nolibxml.lo
#   CC       topology-xml-libxml.lo
#   CC       topology-opencl.lo
#   CC       topology-cuda.lo
#   CC       topology-nvml.lo
#   CC       topology-linux.lo
#   CC       topology-hardwired.lo
#   CC       topology-x86.lo
#   CCLD     libhwloc.la
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/src'
# Making all in include
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/include'
# make[1]: Nothing to be done for 'all'.
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/include'
# Making all in utils
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils'
# Making all in hwloc
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/hwloc'
#   CC       hwloc-annotate.o
#   CCLD     hwloc-annotate
#   CC       hwloc-assembler.o
#   CCLD     hwloc-assembler
#   CC       hwloc-bind.o
#   CCLD     hwloc-bind
#   CC       hwloc-calc.o
#   CCLD     hwloc-calc
#   CC       hwloc-diff.o
#   CCLD     hwloc-diff
#   CC       hwloc-distances.o
#   CCLD     hwloc-distances
#   CC       hwloc-distrib.o
#   CCLD     hwloc-distrib
#   CC       hwloc-info.o
#   CCLD     hwloc-info
#   CC       hwloc-patch.o
#   CCLD     hwloc-patch
#   CC       hwloc-ps.o
# hwloc-ps.c: In function ‘one_process’:
# hwloc-ps.c:192:21: warning: ignoring return value of ‘read’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   192 |                     read(commfile, tids[i-1].name, TIDNAME_MAX);
#       |                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   CCLD     hwloc-ps
#   CC       hwloc_dump_hwdata-hwloc-dump-hwdata.o
#   CC       hwloc_dump_hwdata-hwloc-dump-hwdata-knl.o
#   CCLD     hwloc-dump-hwdata
# Creating hwloc.7 man page...
# Creating hwloc-annotate.1 man page...
# Creating hwloc-assembler.1 man page...
# Creating hwloc-assembler-remote.1 man page...
# Creating hwloc-bind.1 man page...
# Creating hwloc-calc.1 man page...
# Creating hwloc-compress-dir.1 man page...
# Creating hwloc-diff.1 man page...
# Creating hwloc-distances.1 man page...
# Creating hwloc-distrib.1 man page...
# Creating hwloc-info.1 man page...
# Creating hwloc-patch.1 man page...
# Creating hwloc-gather-topology.1 man page...
# Creating hwloc-ps.1 man page...
# Creating hwloc-dump-hwdata.1 man page...
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/hwloc'
# Making all in lstopo
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/lstopo'
#   CC       lstopo_no_graphics-lstopo.o
#   CC       lstopo_no_graphics-lstopo-color.o
#   CC       lstopo_no_graphics-lstopo-draw.o
#   CC       lstopo_no_graphics-lstopo-fig.o
#   CC       lstopo_no_graphics-lstopo-ascii.o
#   CC       lstopo_no_graphics-lstopo-text.o
#   CC       lstopo_no_graphics-lstopo-xml.o
#   CCLD     lstopo-no-graphics
#   CC       lstopo-lstopo.o
#   CC       lstopo-lstopo-color.o
#   CC       lstopo-lstopo-draw.o
#   CC       lstopo-lstopo-fig.o
#   CC       lstopo-lstopo-ascii.o
#   CC       lstopo-lstopo-text.o
#   CC       lstopo-lstopo-xml.o
#   CC       lstopo-lstopo-cairo.o
#   CCLD     lstopo
# Creating lstopo-no-graphics.1 man page...
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/lstopo'
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils'
# make[2]: Nothing to be done for 'all-am'.
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils'
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils'
# Making all in tests
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests'
# Making all in .
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests'
# make[2]: Nothing to be done for 'all-am'.
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests'
# Making all in ports
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/ports'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/ports'
# Making all in xml
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/xml'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/xml'
# Making all in linux
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux'
# Making all in .
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux'
# make[3]: Nothing to be done for 'all-am'.
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux'
# Making all in allowed
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux/allowed'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux/allowed'
# Making all in gather
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux/gather'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux/gather'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux'
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests'
# Making all in contrib/systemd
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/contrib/systemd'
# Creating hwloc-dump-hwdata.service...
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/contrib/systemd'
# Making all in doc
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc'
# make  all-recursive
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc'
# Making all in examples
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc/examples'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc/examples'
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc'
# make[3]: Nothing to be done for 'all-am'.
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc'
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc'
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13'
# make[1]: Nothing to be done for 'all-am'.
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13'
# Making install in src
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/src'
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/src'
#  /usr/bin/mkdir -p '/usr/local/lib'
#  /bin/bash ../libtool   --mode=install /usr/bin/install -c   libhwloc.la '/usr/local/lib'
# libtool: install: /usr/bin/install -c .libs/libhwloc.so.5.7.10 /usr/local/lib/libhwloc.so.5.7.10
# libtool: install: (cd /usr/local/lib && { ln -s -f libhwloc.so.5.7.10 libhwloc.so.5 || { rm -f libhwloc.so.5 && ln -s libhwloc.so.5.7.10 libhwloc.so.5; }; })
# libtool: install: (cd /usr/local/lib && { ln -s -f libhwloc.so.5.7.10 libhwloc.so || { rm -f libhwloc.so && ln -s libhwloc.so.5.7.10 libhwloc.so; }; })
# libtool: install: /usr/bin/install -c .libs/libhwloc.lai /usr/local/lib/libhwloc.la
# libtool: finish: PATH="/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/sbin" ldconfig -n /usr/local/lib
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /usr/local/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the '-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the 'LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the 'LD_RUN_PATH' environment variable
#      during linking
#    - use the '-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to '/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
# make  install-exec-hook
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/src'
# make[3]: Nothing to be done for 'install-exec-hook'.
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/src'
#  /usr/bin/mkdir -p '/usr/local/share/hwloc'
#  /usr/bin/install -c -m 644 ./hwloc.dtd '/usr/local/share/hwloc'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/src'
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/src'
# Making install in include
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/include'
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/include'
# make[2]: Nothing to be done for 'install-exec-am'.
#  /usr/bin/mkdir -p '/usr/local/include'
#  /usr/bin/install -c -m 644 hwloc.h '/usr/local/include'
#  /usr/bin/mkdir -p '/usr/local/include/hwloc'
#  /usr/bin/install -c -m 644 hwloc/bitmap.h hwloc/helper.h hwloc/inlines.h hwloc/diff.h hwloc/myriexpress.h hwloc/openfabrics-verbs.h hwloc/opencl.h hwloc/cuda.h hwloc/cudart.h hwloc/nvml.h hwloc/plugins.h hwloc/gl.h hwloc/intel-mic.h hwloc/rename.h hwloc/deprecated.h hwloc/linux.h hwloc/linux-libnuma.h hwloc/glibc-sched.h '/usr/local/include/hwloc'
#  /usr/bin/mkdir -p '/usr/local/include/hwloc/autogen'
#  /usr/bin/install -c -m 644 hwloc/autogen/config.h '/usr/local/include/hwloc/autogen'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/include'
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/include'
# Making install in utils
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils'
# Making install in hwloc
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/hwloc'
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/hwloc'
#  /usr/bin/mkdir -p '/usr/local/bin'
#   /bin/bash ../../libtool   --mode=install /usr/bin/install -c hwloc-annotate hwloc-assembler hwloc-bind hwloc-calc hwloc-diff hwloc-distances hwloc-distrib hwloc-info hwloc-patch hwloc-ps '/usr/local/bin'
# libtool: install: /usr/bin/install -c .libs/hwloc-annotate /usr/local/bin/hwloc-annotate
# libtool: install: /usr/bin/install -c .libs/hwloc-assembler /usr/local/bin/hwloc-assembler
# libtool: install: /usr/bin/install -c .libs/hwloc-bind /usr/local/bin/hwloc-bind
# libtool: install: /usr/bin/install -c .libs/hwloc-calc /usr/local/bin/hwloc-calc
# libtool: install: /usr/bin/install -c .libs/hwloc-diff /usr/local/bin/hwloc-diff
# libtool: install: /usr/bin/install -c .libs/hwloc-distances /usr/local/bin/hwloc-distances
# libtool: install: /usr/bin/install -c .libs/hwloc-distrib /usr/local/bin/hwloc-distrib
# libtool: install: /usr/bin/install -c .libs/hwloc-info /usr/local/bin/hwloc-info
# libtool: install: /usr/bin/install -c .libs/hwloc-patch /usr/local/bin/hwloc-patch
# libtool: install: /usr/bin/install -c .libs/hwloc-ps /usr/local/bin/hwloc-ps
#  /usr/bin/mkdir -p '/usr/local/bin'
#  /usr/bin/install -c hwloc-assembler-remote hwloc-compress-dir hwloc-gather-topology '/usr/local/bin'
#  /usr/bin/mkdir -p '/usr/local/sbin'
#   /bin/bash ../../libtool   --mode=install /usr/bin/install -c hwloc-dump-hwdata '/usr/local/sbin'
# libtool: install: /usr/bin/install -c .libs/hwloc-dump-hwdata /usr/local/sbin/hwloc-dump-hwdata
# make  install-exec-hook
# make[4]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/hwloc'
# /usr/bin/sed -e 's/HWLOC_top_builddir\/utils\/hwloc/bindir/' -e 's/HWLOC_top_builddir\/utils\/lstopo/bindir/' -e '/HWLOC_top_builddir/d' /usr/local/bin/hwloc-assembler-remote > /usr/local/bin/hwloc-assembler-remote.tmp && mv -f /usr/local/bin/hwloc-assembler-remote.tmp /usr/local/bin/hwloc-assembler-remote
# /usr/bin/sed -e 's/HWLOC_top_builddir\/utils\/hwloc/bindir/' -e 's/HWLOC_top_builddir\/utils\/lstopo/bindir/' -e '/HWLOC_top_builddir/d' /usr/local/bin/hwloc-compress-dir > /usr/local/bin/hwloc-compress-dir.tmp && mv -f /usr/local/bin/hwloc-compress-dir.tmp /usr/local/bin/hwloc-compress-dir
# chmod +x /usr/local/bin/hwloc-assembler-remote /usr/local/bin/hwloc-compress-dir
# /usr/bin/sed -e 's/HWLOC_top_builddir\/utils\/lstopo/bindir/' -e '/HWLOC_top_builddir/d' /usr/local/bin/hwloc-gather-topology > /usr/local/bin/hwloc-gather-topology.tmp && mv -f /usr/local/bin/hwloc-gather-topology.tmp /usr/local/bin/hwloc-gather-topology
# chmod +x /usr/local/bin/hwloc-gather-topology
# make[4]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/hwloc'
#  /usr/bin/mkdir -p '/usr/local/share/man/man1'
#  /usr/bin/install -c -m 644 hwloc-annotate.1 hwloc-assembler.1 hwloc-assembler-remote.1 hwloc-bind.1 hwloc-calc.1 hwloc-compress-dir.1 hwloc-diff.1 hwloc-distances.1 hwloc-distrib.1 hwloc-info.1 hwloc-patch.1 hwloc-gather-topology.1 hwloc-ps.1 hwloc-dump-hwdata.1 '/usr/local/share/man/man1'
#  /usr/bin/mkdir -p '/usr/local/share/man/man7'
#  /usr/bin/install -c -m 644 hwloc.7 '/usr/local/share/man/man7'
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/hwloc'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/hwloc'
# Making install in lstopo
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/lstopo'
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/lstopo'
#  /usr/bin/mkdir -p '/usr/local/bin'
#   /bin/bash ../../libtool   --mode=install /usr/bin/install -c lstopo-no-graphics lstopo '/usr/local/bin'
# libtool: install: /usr/bin/install -c .libs/lstopo-no-graphics /usr/local/bin/lstopo-no-graphics
# libtool: install: /usr/bin/install -c .libs/lstopo /usr/local/bin/lstopo
# make  install-exec-hook
# make[4]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/lstopo'
# rm -f /usr/local/bin/hwloc-ls
# cd /usr/local/bin && ln -s lstopo-no-graphics hwloc-ls
# make[4]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/lstopo'
#  /usr/bin/mkdir -p '/usr/local/share/applications'
#  /usr/bin/install -c -m 644 lstopo.desktop '/usr/local/share/applications'
#  /usr/bin/mkdir -p '/usr/local/share/man/man1'
#  /usr/bin/install -c -m 644 lstopo-no-graphics.1 '/usr/local/share/man/man1'
# make  install-data-hook
# make[4]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/lstopo'
# rm -f /usr/local/share/man/man1/hwloc-ls.1
# cd /usr/local/share/man/man1 && ln -s lstopo-no-graphics.1 hwloc-ls.1
# rm -f /usr/local/share/man/man1/lstopo.1
# cd /usr/local/share/man/man1 && ln -s lstopo-no-graphics.1 lstopo.1
# make[4]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/lstopo'
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/lstopo'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils/lstopo'
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils'
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils'
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/utils'
# Making install in tests
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests'
# Making install in .
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests'
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests'
# Making install in ports
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/ports'
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/ports'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/ports'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/ports'
# Making install in xml
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/xml'
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/xml'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/xml'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/xml'
# Making install in linux
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux'
# Making install in .
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux'
# make[4]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux'
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux'
# Making install in allowed
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux/allowed'
# make[4]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux/allowed'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux/allowed'
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux/allowed'
# Making install in gather
# make[3]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux/gather'
# make[4]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux/gather'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux/gather'
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux/gather'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests/linux'
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/tests'
# Making install in contrib/systemd
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/contrib/systemd'
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/contrib/systemd'
# make[2]: Nothing to be done for 'install-exec-am'.
#  /usr/bin/mkdir -p '/usr/local/share/hwloc'
#  /usr/bin/install -c -m 644 hwloc-dump-hwdata.service '/usr/local/share/hwloc'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/contrib/systemd'
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/contrib/systemd'
# Making install in doc
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc'
# make  install-recursive
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc'
3 '/usr/local/share/man/man3'
#  /usr/bin/mkdir -p '/usr/local/share/man/man3'
#  /usr/bin/install -c -m 644 doxygen-doc/man/man3/hwlocality_tinker.3 doxygen-doc/man/man3/hwloc_topology_insert_misc_object_by_cpuset.3 doxygen-doc/man/man3/hwloc_topology_insert_misc_object_by_parent.3 doxygen-doc/man/man3/HWLOC_RESTRICT_FLAG_ADAPT_DISTANCES.3 doxygen-doc/man/man3/HWLOC_RESTRICT_FLAG_ADAPT_IO.3 doxygen-doc/man/man3/HWLOC_RESTRICT_FLAG_ADAPT_MISC.3 doxygen-doc/man/man3/hwloc_restrict_flags_e.3 doxygen-doc/man/man3/hwloc_topology_restrict.3 '/usr/local/share/man/man3'
#  /usr/bin/mkdir -p '/usr/local/share/man/man3'
#  /usr/bin/install -c -m 644 doxygen-doc/man/man3/hwlocality_xmlexport.3 doxygen-doc/man/man3/hwloc_topology_export_xml.3 doxygen-doc/man/man3/hwloc_topology_export_xmlbuffer.3 doxygen-doc/man/man3/hwloc_free_xmlbuffer.3 doxygen-doc/man/man3/hwloc_topology_set_userdata_export_callback.3 doxygen-doc/man/man3/hwloc_export_obj_userdata.3 doxygen-doc/man/man3/hwloc_export_obj_userdata_base64.3 doxygen-doc/man/man3/hwloc_topology_set_userdata_import_callback.3 '/usr/local/share/man/man3'
#  /usr/bin/mkdir -p '/usr/local/share/doc/hwloc'
#  /usr/bin/install -c -m 644 doxygen-doc/hwloc-a4.pdf doxygen-doc/hwloc-letter.pdf '/usr/local/share/doc/hwloc'
# make[4]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc'
# make[3]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc'
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13/doc'
# make[1]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13'
# make[2]: Entering directory '/content/drive/MyDrive/gmx/hwloc-1.11.13'
# make[2]: Nothing to be done for 'install-exec-am'.
#  /usr/bin/mkdir -p '/usr/local/share/hwloc'
#  /usr/bin/install -c -m 644 contrib/hwloc-valgrind.supp '/usr/local/share/hwloc'
#  /usr/bin/mkdir -p '/usr/local/lib/pkgconfig'
#  /usr/bin/install -c -m 644 hwloc.pc '/usr/local/lib/pkgconfig'
# make[2]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13'
# make[1]: Leaving directory '/content/drive/MyDrive/gmx/hwloc-1.11.13'
# /content/drive/MyDrive/gmx

# %%
# Download GROMACS source code
# !wget ftp://ftp.gromacs.org/gromacs/gromacs-2023.1.tar.gz
# !tar xfz gromacs-2023.1.tar.gz
# Out:
# --2025-07-14 18:33:20--  ftp://ftp.gromacs.org/gromacs/gromacs-2023.1.tar.gz
#            => ‘gromacs-2023.1.tar.gz’
# Resolving ftp.gromacs.org (ftp.gromacs.org)... 130.237.11.165, 2001:6b0:1:1191:216:3eff:fec7:6e30
# Connecting to ftp.gromacs.org (ftp.gromacs.org)|130.237.11.165|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gromacs ... done.
# ==> SIZE gromacs-2023.1.tar.gz ... 41934072
# ==> PASV ... done.    ==> RETR gromacs-2023.1.tar.gz ... done.
# Length: 41934072 (40M) (unauthoritative)
#
# gromacs-2023.1.tar. 100%[===================>]  39.99M  13.8MB/s    in 2.9s
#
# 2025-07-14 18:33:26 (13.8 MB/s) - ‘gromacs-2023.1.tar.gz’ saved [41934072]

# %%
#Use system’s FFTW instead of the managed build
# !apt-get update && apt-get install -y libfftw3-dev
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libfftw3-dev is already the newest version (3.3.8-2ubuntu8).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.

# %%
# Run CMake to configure GROMACS installation path
# !cmake -B "/content/drive/MyDrive/gmx/gromacs-2023.1/build" \
  -S "/content/drive/MyDrive/gmx/gromacs-2023.1" \
  -DGMX_BUILD_OWN_FFTW=ON \
  -DREGRESSIONTEST_DOWNLOAD=ON \
  -DGMX_GPU=CUDA \
  -DGMX_MPI=OFF \
  -DGMX_OPENMP=OFF \
  -DGMX_DOUBLE=OFF \
  -DCMAKE_INSTALL_PREFIX="/content/drive/MyDrive/gmx/gromacs" \
# -- [download 89% complete]
# -- [download 90% complete]
# -- [download 91% complete]
# -- [download 93% complete]
# -- [download 94% complete]
# -- [download 95% complete]
# -- [download 96% complete]
# -- [download 97% complete]
# -- [download 98% complete]
# -- [download 99% complete]
# -- [download 100% complete]
# -- Configuring done (25.3s)
# -- Generating done (20.0s)
# -- Build files have been written to: /content/drive/MyDrive/gmx/gromacs-2023.1/build

# %%
# Give execute permissions to the configure script explicitly:
# !chmod +x /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/configure

# %%
# Build and install GROMACS
# !cmake --build "/content/drive/MyDrive/gmx/gromacs-2023.1/build" -j4
# !cmake --build "/content/drive/MyDrive/gmx/gromacs-2023.1/build" --target install
# Out:
# [ -3%] Generating release version information
# [ -3%] Performing configure step for 'fftwBuild'
# [ -3%] Built target release-version-info
# [ -3%] Built target scanner
# checking for a BSD-compatible install... [ -1%] Built target tng_io_obj
# /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... [ -1%] Built target lmfit_objlib
# yes
# checking whether make supports nested variables... yes
# checking whether to enable maintainer-specific portions of Makefiles... no
# checking build system type... [ -1%] Built target tng_io_zlib
# x86_64-pc-linux-gnu
# checking host system type... x86_64-pc-linux-gnu
# checking for gcc... gcc
# [ -1%] Building CXX object src/gromacs/linearalgebra/CMakeFiles/linearalgebra.dir/eigensolver.cpp.o
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables... [  1%] Built target thread_mpi
#
# checking whether we are cross compiling... [  1%] Building CXX object src/gromacs/options/CMakeFiles/options.dir/abstractoption.cpp.o
# no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... [  1%] Built target muparser
# yes
# checking for gcc option to accept ISO C89... [  1%] Building CXX object src/external/googletest/googletest/CMakeFiles/gtest.dir/src/gtest-all.cc.o
# none needed
# checking whether gcc understands -c and -o together... yes
# checking for style of include used by make... GNU
# checking dependency style of gcc... gcc3
# checking for C compiler vendor... gnu
# checking for gcc option to accept ISO C99... none needed
# checking for gcc option to accept ISO Standard C... (cached) none needed
# checking whether ln -s works... yes
# checking whether make sets $(MAKE)... (cached) yes
# checking how to print strings... printf
# checking for a sed that does not truncate output... /usr/bin/sed
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking for fgrep... /usr/bin/grep -F
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking the maximum length of command line arguments... 1572864
# checking how to convert x86_64-pc-linux-gnu file names to x86_64-pc-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-pc-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... dlltool
# checking how to associate runtime and link libraries... printf %s\n
# checking for ar... ar
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking command to parse /usr/bin/nm -B output from gcc object... [  1%] Building CXX object src/gromacs/linearalgebra/CMakeFiles/linearalgebra.dir/gmx_arpack.cpp.o
# ok
# checking for sysroot... no
# checking for a working dd... /usr/bin/dd
# checking how to truncate binary pipes... /usr/bin/dd bs=4096 count=1
# checking for mt... no
# checking if : is a manifest tool... no
# checking how to run the C preprocessor... gcc -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... [  1%] Building CXX object src/gromacs/options/CMakeFiles/options.dir/abstractsection.cpp.o
# yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if gcc supports -fno-rtti -fno-exceptions... no
# checking for gcc option to produce PIC... -fPIC -DPIC
# checking if gcc PIC flag -fPIC -DPIC works... yes
# checking if gcc static flag -static works... yes
# checking if gcc supports -c -o file.o... yes
# checking if gcc supports -c -o file.o... (cached) yes
# checking whether the gcc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... [  1%] Building CXX object src/gromacs/options/CMakeFiles/options.dir/basicoptions.cpp.o
# yes
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... no
# checking whether to build static libraries... yes
# checking for ranlib... (cached) ranlib
# checking for ocamlbuild... no
# checking whether C compiler accepts -mtune=native... yes
# checking whether C compiler accepts -malign-double... yes
# checking whether C compiler accepts -fstrict-aliasing... yes
# checking whether C compiler accepts -fno-schedule-insns... yes
# checking whether C compiler accepts -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns... yes
# checking whether C compiler accepts -msse... yes
# checking whether C compiler accepts -mavx... yes
# checking whether C compiler accepts -march=core-avx2... yes
# checking whether C compiler accepts -mfma... yes
# checking whether C compiler accepts -mavx512f... yes
# checking for ANSI C header files... (cached) yes
# checking fcntl.h usability... yes
# checking fcntl.h presence... yes
# checking for fcntl.h... yes
# checking fenv.h usability... yes
# checking fenv.h presence... yes
# checking for fenv.h... yes
# checking limits.h usability... yes
# checking limits.h presence... yes
# checking for limits.h... yes
# checking malloc.h usability... yes
# checking malloc.h presence... yes
# checking for malloc.h... yes
# checking stddef.h usability... yes
# checking stddef.h presence... yes
# checking for stddef.h... yes
# checking sys/time.h usability... yes
# checking sys/time.h presence... yes
# checking for sys/time.h... yes
# checking altivec.h usability... [  1%] Building CXX object src/gromacs/linearalgebra/CMakeFiles/linearalgebra.dir/matrix.cpp.o
# no
# checking altivec.h presence... no
# checking for altivec.h... no
# checking for an ANSI C-conforming const... yes
# checking for inline... inline
# checking for size_t... yes
# checking for uint32_t... yes
# checking for uint64_t... yes
# checking whether time.h and sys/time.h may both be included... yes
# checking for long double... yes
# checking for hrtime_t... no
# checking size of int... 4
# checking size of unsigned int... 4
# checking size of long... 8
# checking size of unsigned long... [  1%] Building CXX object src/gromacs/linearalgebra/CMakeFiles/linearalgebra.dir/sparsematrix.cpp.o
# 8
# checking size of long long... 8
# checking size of unsigned long long... 8
# checking size of size_t... [  1%] Built target linearalgebra
# [  1%] Building CXX object src/programs/CMakeFiles/mdrun_objlib.dir/mdrun/mdrun.cpp.o
# 8
# checking size of ptrdiff_t... 8
# checking for ptrdiff_t... yes
# checking for uintptr_t... yes
# checking size of float... 4
# checking size of double... 8
# checking size of fftw_r2r_kind... 4
# checking for working alloca.h... yes
# checking for alloca... yes
# checking for working strtod... yes
# checking for vprintf... yes
# checking for _doprnt... no
# checking for sin in -lm... yes
# checking for BSDgettimeofday... no
# checking for gettimeofday... yes
# checking for gethrtime... no
# checking for read_real_time... no
# checking for time_base_to_time... [  1%] Building CXX object src/programs/CMakeFiles/mdrun_objlib.dir/mdrun/nonbonded_bench.cpp.o
# no
# checking for drand48... yes
# checking for sqrt... yes
# checking for memset... yes
# checking for posix_memalign... yes
# [  1%] Building CXX object src/gromacs/options/CMakeFiles/options.dir/behaviorcollection.cpp.o
# checking for memalign... yes
# checking for _mm_malloc... no
# checking for _mm_free... no
# checking for clock_gettime... [  1%] Building CXX object src/gromacs/options/CMakeFiles/options.dir/filenameoption.cpp.o
# yes
# checking for mach_absolute_time... no
# checking for sysctl... [  1%] Linking CXX shared library ../../../../lib/libgtest.so
# no
# checking for abort... yes
# checking for sinl... [  1%] Built target gtest
# [  1%] Building CXX object src/gromacs/options/CMakeFiles/options.dir/filenameoptionmanager.cpp.o
# [  1%] Built target mdrun_objlib
# yes
# [  1%] Building CXX object src/gromacs/options/CMakeFiles/options.dir/options.cpp.o
# checking for cosl... yes
# checking for snprintf... yes
# checking for memmove... yes
# checking for strchr... yes
# checking for getpagesize... yes
# checking whether sinl is declared... yes
# checking whether cosl is declared... yes
# checking whether sinq is declared... no
# checking whether cosq is declared... no
# checking whether memalign is declared... yes
# checking whether drand48 is declared... yes
# checking whether srand48 is declared... yes
# checking whether posix_memalign is declared... [  1%] Building CXX object src/gromacs/options/CMakeFiles/options.dir/optionsassigner.cpp.o
# yes
# checking for _rtc intrinsic... no
# checking for isnan... [  1%] Building CXX object src/gromacs/options/CMakeFiles/options.dir/optionsection.cpp.o
# [  1%] Building CXX object src/gromacs/options/CMakeFiles/options.dir/optionsvisitor.cpp.o
# yes
# checking whether C compiler accepts -mpreferred-stack-boundary=4... yes
# checking whether the stack is at least 8-byte aligned by gcc... checking whether C compiler accepts -malign-double... (cached) yes
# yes
# checking whether a cycle counter is available... yes
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# [  1%] Building CXX object src/gromacs/options/CMakeFiles/options.dir/timeunitmanager.cpp.o
# [  3%] Building CXX object src/gromacs/options/CMakeFiles/options.dir/treesupport.cpp.o
# [  5%] Building CXX object src/programs/CMakeFiles/gmx_objlib.dir/gmx.cpp.o
# config.status: creating Makefile
# config.status: creating support/Makefile
# config.status: creating genfft/Makefile
# config.status: creating kernel/Makefile
# config.status: creating simd-support/Makefile
# config.status: creating dft/Makefile
# config.status: creating dft/scalar/Makefile
# config.status: creating dft/scalar/codelets/Makefile
# config.status: creating dft/simd/Makefile
# config.status: creating dft/simd/common/Makefile
# [  5%] Building CXX object src/programs/CMakeFiles/gmx_objlib.dir/legacymodules.cpp.o
# config.status: creating dft/simd/sse2/Makefile
# config.status: creating dft/simd/avx/Makefile
# config.status: creating dft/simd/avx-128-fma/Makefile
# config.status: creating dft/simd/avx2/Makefile
# config.status: creating dft/simd/avx2-128/Makefile
# config.status: creating dft/simd/avx512/Makefile
# config.status: creating dft/simd/kcvi/Makefile
# config.status: creating dft/simd/altivec/Makefile
# config.status: creating dft/simd/vsx/Makefile
# config.status: creating dft/simd/neon/Makefile
# config.status: creating dft/simd/generic-simd128/Makefile
# config.status: creating dft/simd/generic-simd256/Makefile
# config.status: creating rdft/Makefile
# config.status: creating rdft/scalar/Makefile
# [  5%] Built target gmx_objlib
# config.status: creating rdft/scalar/r2cf/Makefile
# [  5%] Building CXX object src/gromacs/pulling/CMakeFiles/pulling.dir/output.cpp.o
# [  5%] Building CXX object src/external/googletest/googlemock/CMakeFiles/gmock.dir/src/gmock-all.cc.o
# [  5%] Built target options
# [  5%] Building CXX object src/gromacs/pulling/CMakeFiles/pulling.dir/pull.cpp.o
# config.status: creating rdft/scalar/r2cb/Makefile
# config.status: creating rdft/scalar/r2r/Makefile
# config.status: creating rdft/simd/Makefile
# config.status: creating rdft/simd/common/Makefile
# config.status: creating rdft/simd/sse2/Makefile
# config.status: creating rdft/simd/avx/Makefile
# config.status: creating rdft/simd/avx-128-fma/Makefile
# config.status: creating rdft/simd/avx2/Makefile
# config.status: creating rdft/simd/avx2-128/Makefile
# config.status: creating rdft/simd/avx512/Makefile
# config.status: creating rdft/simd/kcvi/Makefile
# config.status: creating rdft/simd/altivec/Makefile
# config.status: creating rdft/simd/vsx/Makefile
# config.status: creating rdft/simd/neon/Makefile
# config.status: creating rdft/simd/generic-simd128/Makefile
# config.status: creating rdft/simd/generic-simd256/Makefile
# config.status: creating reodft/Makefile
# config.status: creating threads/Makefile
# config.status: creating api/Makefile
# config.status: creating mpi/Makefile
# config.status: creating libbench2/Makefile
# config.status: creating tests/Makefile
# config.status: creating doc/Makefile
# config.status: creating doc/FAQ/Makefile
# config.status: creating tools/Makefile
# config.status: creating tools/fftw_wisdom.1
# config.status: creating tools/fftw-wisdom-to-conf
# config.status: creating m4/Makefile
# config.status: creating fftw.pc
# config.status: creating config.h
# config.status: executing depfiles commands
# [  5%] Building CXX object src/gromacs/pulling/CMakeFiles/pulling.dir/pull_rotation.cpp.o
# [  5%] Building CXX object src/gromacs/pulling/CMakeFiles/pulling.dir/pullcoordexpressionparser.cpp.o
# [  5%] Linking CXX shared library ../../../../lib/libgmock.so
# [  5%] Built target gmock
# [  5%] Building CXX object src/gromacs/pulling/CMakeFiles/pulling.dir/pullutil.cpp.o
# [  5%] Building CXX object src/gromacs/pulling/CMakeFiles/pulling.dir/transformationcoordinate.cpp.o
# [  5%] Built target pulling
# [  5%] Building CXX object src/gromacs/taskassignment/CMakeFiles/taskassignment.dir/decidegpuusage.cpp.o
# [  6%] Building CXX object src/gromacs/taskassignment/CMakeFiles/taskassignment.dir/decidesimulationworkload.cpp.o
# [  6%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/andersentemperaturecoupling.cpp.o
# [  6%] Building CXX object src/gromacs/taskassignment/CMakeFiles/taskassignment.dir/findallgputasks.cpp.o
# [  6%] Building CXX object src/gromacs/taskassignment/CMakeFiles/taskassignment.dir/reportgpuusage.cpp.o
# [  6%] Building CXX object src/gromacs/taskassignment/CMakeFiles/taskassignment.dir/resourcedivision.cpp.o
# [  6%] Building CXX object src/gromacs/taskassignment/CMakeFiles/taskassignment.dir/taskassignment.cpp.o
# [  6%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/checkpointhelper.cpp.o
# [  6%] Building CXX object src/gromacs/taskassignment/CMakeFiles/taskassignment.dir/usergpuids.cpp.o
# [  6%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/compositesimulatorelement.cpp.o
# [  6%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/computeglobalselement.cpp.o
# [  6%] Built target taskassignment
# [  6%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/constraintelement.cpp.o
# [  6%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/domdechelper.cpp.o
# [  8%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/energydata.cpp.o
# [  8%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/expandedensembleelement.cpp.o
# [  8%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/firstorderpressurecoupling.cpp.o
# config.status: executing libtool commands
# [  8%] Performing build step for 'fftwBuild'
# Making all in support
# Making all in kernel
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT align.lo -MD -MP -MF .deps/align.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/align.c  -fPIC -DPIC -o align.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT alloc.lo -MD -MP -MF .deps/alloc.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/alloc.c  -fPIC -DPIC -o alloc.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT assert.lo -MD -MP -MF .deps/assert.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/assert.c  -fPIC -DPIC -o assert.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT awake.lo -MD -MP -MF .deps/awake.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/awake.c  -fPIC -DPIC -o awake.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT buffered.lo -MD -MP -MF .deps/buffered.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/buffered.c  -fPIC -DPIC -o buffered.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT cpy1d.lo -MD -MP -MF .deps/cpy1d.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/cpy1d.c  -fPIC -DPIC -o cpy1d.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT cpy2d-pair.lo -MD -MP -MF .deps/cpy2d-pair.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/cpy2d-pair.c  -fPIC -DPIC -o cpy2d-pair.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT cpy2d.lo -MD -MP -MF .deps/cpy2d.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/cpy2d.c  -fPIC -DPIC -o cpy2d.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT ct.lo -MD -MP -MF .deps/ct.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/ct.c  -fPIC -DPIC -o ct.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT debug.lo -MD -MP -MF .deps/debug.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/debug.c  -fPIC -DPIC -o debug.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT extract-reim.lo -MD -MP -MF .deps/extract-reim.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/extract-reim.c  -fPIC -DPIC -o extract-reim.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT hash.lo -MD -MP -MF .deps/hash.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/hash.c  -fPIC -DPIC -o hash.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT iabs.lo -MD -MP -MF .deps/iabs.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/iabs.c  -fPIC -DPIC -o iabs.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT kalloc.lo -MD -MP -MF .deps/kalloc.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/kalloc.c  -fPIC -DPIC -o kalloc.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT md5-1.lo -MD -MP -MF .deps/md5-1.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/md5-1.c  -fPIC -DPIC -o md5-1.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT md5.lo -MD -MP -MF .deps/md5.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/md5.c  -fPIC -DPIC -o md5.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT minmax.lo -MD -MP -MF .deps/minmax.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/minmax.c  -fPIC -DPIC -o minmax.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT ops.lo -MD -MP -MF .deps/ops.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/ops.c  -fPIC -DPIC -o ops.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT pickdim.lo -MD -MP -MF .deps/pickdim.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/pickdim.c  -fPIC -DPIC -o pickdim.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT plan.lo -MD -MP -MF .deps/plan.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/plan.c  -fPIC -DPIC -o plan.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT planner.lo -MD -MP -MF .deps/planner.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/planner.c  -fPIC -DPIC -o planner.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT primes.lo -MD -MP -MF .deps/primes.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/primes.c  -fPIC -DPIC -o primes.o
# [  8%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/forceelement.cpp.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT print.lo -MD -MP -MF .deps/print.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/print.c  -fPIC -DPIC -o print.o
# [  8%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/freeenergyperturbationdata.cpp.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT problem.lo -MD -MP -MF .deps/problem.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/problem.c  -fPIC -DPIC -o problem.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT rader.lo -MD -MP -MF .deps/rader.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/rader.c  -fPIC -DPIC -o rader.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT scan.lo -MD -MP -MF .deps/scan.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/scan.c  -fPIC -DPIC -o scan.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT solver.lo -MD -MP -MF .deps/solver.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/solver.c  -fPIC -DPIC -o solver.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT solvtab.lo -MD -MP -MF .deps/solvtab.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/solvtab.c  -fPIC -DPIC -o solvtab.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT stride.lo -MD -MP -MF .deps/stride.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/stride.c  -fPIC -DPIC -o stride.o
# [  8%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/modularsimulator.cpp.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT tensor.lo -MD -MP -MF .deps/tensor.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/tensor.c  -fPIC -DPIC -o tensor.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT tensor1.lo -MD -MP -MF .deps/tensor1.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/tensor1.c  -fPIC -DPIC -o tensor1.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT tensor2.lo -MD -MP -MF .deps/tensor2.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/tensor2.c  -fPIC -DPIC -o tensor2.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT tensor3.lo -MD -MP -MF .deps/tensor3.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/tensor3.c  -fPIC -DPIC -o tensor3.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT tensor4.lo -MD -MP -MF .deps/tensor4.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/tensor4.c  -fPIC -DPIC -o tensor4.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT tensor5.lo -MD -MP -MF .deps/tensor5.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/tensor5.c  -fPIC -DPIC -o tensor5.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT tensor7.lo -MD -MP -MF .deps/tensor7.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/tensor7.c  -fPIC -DPIC -o tensor7.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT tensor8.lo -MD -MP -MF .deps/tensor8.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/tensor8.c  -fPIC -DPIC -o tensor8.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT tensor9.lo -MD -MP -MF .deps/tensor9.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/tensor9.c  -fPIC -DPIC -o tensor9.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT tile2d.lo -MD -MP -MF .deps/tile2d.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/tile2d.c  -fPIC -DPIC -o tile2d.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT timer.lo -MD -MP -MF .deps/timer.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/timer.c  -fPIC -DPIC -o timer.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT transpose.lo -MD -MP -MF .deps/transpose.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/transpose.c  -fPIC -DPIC -o transpose.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT trig.lo -MD -MP -MF .deps/trig.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/trig.c  -fPIC -DPIC -o trig.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT twiddle.lo -MD -MP -MF .deps/twiddle.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/kernel/twiddle.c  -fPIC -DPIC -o twiddle.o
# libtool: link: ar cru .libs/libkernel.a  align.o alloc.o assert.o awake.o buffered.o cpy1d.o cpy2d-pair.o cpy2d.o ct.o debug.o extract-reim.o hash.o iabs.o kalloc.o md5-1.o md5.o minmax.o ops.o pickdim.o plan.o planner.o primes.o print.o problem.o rader.o scan.o solver.o solvtab.o stride.o tensor.o tensor1.o tensor2.o tensor3.o tensor4.o tensor5.o tensor7.o tensor8.o tensor9.o tile2d.o timer.o transpose.o trig.o twiddle.o
# ar: `u' modifier ignored since `D' is the default (see `U')
# libtool: link: ranlib .libs/libkernel.a
# libtool: link: ( cd ".libs" && rm -f "libkernel.la" && ln -s "../libkernel.la" "libkernel.la" )
# Making all in simd-support
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT taint.lo -MD -MP -MF .deps/taint.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support/taint.c  -fPIC -DPIC -o taint.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT sse2.lo -MD -MP -MF .deps/sse2.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support/sse2.c  -fPIC -DPIC -o sse2.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT avx.lo -MD -MP -MF .deps/avx.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support/avx.c  -fPIC -DPIC -o avx.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT avx-128-fma.lo -MD -MP -MF .deps/avx-128-fma.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support/avx-128-fma.c  -fPIC -DPIC -o avx-128-fma.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT avx2.lo -MD -MP -MF .deps/avx2.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support/avx2.c  -fPIC -DPIC -o avx2.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT avx512.lo -MD -MP -MF .deps/avx512.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support/avx512.c  -fPIC -DPIC -o avx512.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT kcvi.lo -MD -MP -MF .deps/kcvi.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support/kcvi.c  -fPIC -DPIC -o kcvi.o
# [  8%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/mttk.cpp.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT altivec.lo -MD -MP -MF .deps/altivec.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support/altivec.c  -fPIC -DPIC -o altivec.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT vsx.lo -MD -MP -MF .deps/vsx.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support/vsx.c  -fPIC -DPIC -o vsx.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support -I.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT neon.lo -MD -MP -MF .deps/neon.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/simd-support/neon.c  -fPIC -DPIC -o neon.o
# [  8%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/nosehooverchains.cpp.o
# libtool: link: ar cru .libs/libsimd_support.a  taint.o sse2.o avx.o avx-128-fma.o avx2.o avx512.o kcvi.o altivec.o vsx.o neon.o
# ar: `u' modifier ignored since `D' is the default (see `U')
# libtool: link: ranlib .libs/libsimd_support.a
# libtool: link: ( cd ".libs" && rm -f "libsimd_support.la" && ln -s "../libsimd_support.la" "libsimd_support.la" )
# Making all in dft
# Making all in scalar
# Making all in codelets
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/dft/scalar/codelets -I../../.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT n1_2.lo -MD -MP -MF .deps/n1_2.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/dft/scalar/codelets/n1_2.c  -fPIC -DPIC -o n1_2.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/dft/scalar/codelets -I../../.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT n1_3.lo -MD -MP -MF .deps/n1_3.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/dft/scalar/codelets/n1_3.c  -fPIC -DPIC -o n1_3.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/dft/scalar/codelets -I../../.. -I /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -MT n1_4.lo -MD -MP -MF .deps/n1_4.Tpo -c /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/dft/scalar/codelets/n1_4.c  -fPIC -DPIC -o n1_4.o
# [  8%] Building CXX object src/gromacs/modularsimulator/CMakeFiles/modularsimulator.dir/parrinellorahmanbarostat.cpp.o
# ...
#       |                                                      ^~
# In file included from /usr/include/stdio.h:894,
#                  from /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/tools/fftw-wisdom.c:6:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:71:10: note: ‘__builtin___snprintf_chk’ output 1 or more bytes (assuming 1536) into a destination of size 64
#    71 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    72 |                                    __glibc_objsize (__s), __fmt,
#       |                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    73 |                                    __va_arg_pack ());
#       |                                    ~~~~~~~~~~~~~~~~~
# /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/tools/fftw-wisdom.c:303:54: warning: ‘%s’ directive output may be truncated writing up to 1535 bytes into a region of size 64 [-Wformat-truncation=]
#   303 |                          snprintf(ps, sizeof(ps), "%s%s", types[j], canonical_sizes[i]);
#       |                                                      ^~
# In file included from /usr/include/stdio.h:894,
#                  from /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/tools/fftw-wisdom.c:6:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:71:10: note: ‘__builtin___snprintf_chk’ output 1 or more bytes (assuming 1536) into a destination of size 64
#    71 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    72 |                                    __glibc_objsize (__s), __fmt,
#       |                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    73 |                                    __va_arg_pack ());
#       |                                    ~~~~~~~~~~~~~~~~~
# /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/tools/fftw-wisdom.c:303:54: warning: ‘%s’ directive output may be truncated writing up to 1535 bytes into a region of size 64 [-Wformat-truncation=]
#   303 |                          snprintf(ps, sizeof(ps), "%s%s", types[j], canonical_sizes[i]);
#       |                                                      ^~
# In file included from /usr/include/stdio.h:894,
#                  from /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/tools/fftw-wisdom.c:6:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:71:10: note: ‘__builtin___snprintf_chk’ output 1 or more bytes (assuming 1536) into a destination of size 64
#    71 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    72 |                                    __glibc_objsize (__s), __fmt,
#       |                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    73 |                                    __va_arg_pack ());
#       |                                    ~~~~~~~~~~~~~~~~~
# libtool: link: gcc -O3 -fomit-frame-pointer -mtune=native -malign-double -fstrict-aliasing -fno-schedule-insns -o fftwf-wisdom fftwf_wisdom-fftw-wisdom.o ../tests/bench-bench.o ../tests/bench-fftw-bench.o  ../.libs/libfftw3f.a ../libbench2/libbench2.a -lm
# Making all in m4
# [ 10%] Performing install step for 'fftwBuild'
# Making install in support
# Making install in kernel
# Making install in simd-support
# Making install in dft
# Making install in scalar
# Making install in codelets
# Making install in simd
# Making install in common
# Making install in sse2
# Making install in avx
# Making install in avx-128-fma
# Making install in avx2
# Making install in avx2-128
# Making install in avx512
# Making install in kcvi
# Making install in altivec
# Making install in vsx
# Making install in neon
# Making install in generic-simd128
# Making install in generic-simd256
# Making install in rdft
# Making install in scalar
# Making install in r2cf
# Making install in r2cb
# Making install in r2r
# Making install in simd
# Making install in common
# Making install in sse2
# Making install in avx
# Making install in avx-128-fma
# Making install in avx2
# Making install in avx2-128
# Making install in avx512
# Making install in kcvi
# Making install in altivec
# Making install in vsx
# Making install in neon
# Making install in generic-simd128
# Making install in generic-simd256
# Making install in reodft
# Making install in api
#  /usr/bin/mkdir -p '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/include'
#  /usr/bin/mkdir -p '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/include'
#  /usr/bin/install -c -m 644 /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/api/fftw3.h /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/api/fftw3.f /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/api/fftw3l.f03 /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/api/fftw3q.f03 '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/include'
#  /usr/bin/install -c -m 644 fftw3.f03 '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/include'
# Making install in libbench2
# Making install in .
#  /usr/bin/mkdir -p '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/lib'
#  /usr/bin/mkdir -p '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/lib/pkgconfig'
#  /usr/bin/mkdir -p '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/lib/cmake/fftw3'
#  /bin/bash ./libtool   --mode=install /usr/bin/install -c   libfftw3f.la '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/lib'
#  /usr/bin/install -c -m 644 fftw3f.pc '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/lib/pkgconfig'
#  /usr/bin/install -c -m 644 FFTW3fConfig.cmake FFTW3fConfigVersion.cmake '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/lib/cmake/fftw3'
# libtool: install: /usr/bin/install -c .libs/libfftw3f.lai /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/lib/libfftw3f.la
# libtool: install: /usr/bin/install -c .libs/libfftw3f.a /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/lib/libfftw3f.a
# libtool: install: chmod 644 /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/lib/libfftw3f.a
# libtool: install: ranlib /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/lib/libfftw3f.a
# libtool: finish: PATH="/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/sbin" ldconfig -n /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the '-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the 'LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the 'LD_RUN_PATH' environment variable
#      during linking
#    - use the '-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to '/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
# Making install in threads
# Making install in tests
# Making install in mpi
# Making install in doc
# Making install in FAQ
#  /usr/bin/mkdir -p '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/share/info'
#  /usr/bin/install -c -m 644 /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/doc/fftw3.info /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/doc/fftw3.info-1 /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/doc/fftw3.info-2 '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/share/info'
# Making install in tools
#  /usr/bin/mkdir -p '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/bin'
#  /usr/bin/mkdir -p '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/bin'
#  /usr/bin/mkdir -p '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/share/man/man1'
#  /usr/bin/install -c fftw-wisdom-to-conf '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/bin'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c fftwf-wisdom '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/bin'
#  /usr/bin/install -c -m 644 /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/src/fftwBuild/tools/fftw-wisdom-to-conf.1 fftwf-wisdom.1 '/content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/share/man/man1'
# libtool: install: /usr/bin/install -c fftwf-wisdom /content/drive/MyDrive/gmx/gromacs-2023.1/build/src/external/build-fftw/fftwBuild-prefix/bin/fftwf-wisdom
# Making install in m4
# [ 10%] Completed 'fftwBuild'
# [ 10%] Built target fftwBuild
# [ 10%] Generating baseversion-gen.cpp
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/domdec/libgromacs_generated_gpuhaloexchange_impl_gpu.cpp.o
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/domdec/libgromacs_generated_gpuhaloexchange_impl_gpu.cu.o
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/ewald/libgromacs_generated_pme_coordinate_receiver_gpu_impl_gpu.cpp.o
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/ewald/libgromacs_generated_pme_force_sender_gpu_impl_gpu.cpp.o
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/ewald/libgromacs_generated_pme_force_sender_gpu_impl_gpu.cu.o
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/ewald/libgromacs_generated_pme_gather.cu.o
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/ewald/libgromacs_generated_pme_gpu_grid.cu.o
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/ewald/libgromacs_generated_pme_gpu_internal.cpp.o
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/ewald/libgromacs_generated_pme_gpu_program_impl.cu.o
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/ewald/libgromacs_generated_pme_gpu_timings.cpp.o
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/ewald/libgromacs_generated_pme_pp_comm_gpu_impl_gpu.cpp.o
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/ewald/libgromacs_generated_pme_pp_comm_gpu_impl_gpu.cu.o
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/ewald/libgromacs_generated_pme_solve.cu.o
# [ 10%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/ewald/libgromacs_generated_pme_spread.cu.o
# [ 12%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/fft/libgromacs_generated_gpu_3dfft.cpp.o
# [ 12%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/fft/libgromacs_generated_gpu_3dfft_cufft.cu.o
# [ 12%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/fft/libgromacs_generated_gpu_3dfft_impl.cpp.o
# [ 12%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/gpu_utils/libgromacs_generated_device_stream.cu.o
# [ 12%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/gpu_utils/libgromacs_generated_device_stream_manager.cpp.o
# [ 12%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/gpu_utils/libgromacs_generated_gpu_utils.cu.o
# [ 12%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/gpu_utils/libgromacs_generated_pmalloc.cu.o
# [ 12%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/hardware/libgromacs_generated_detecthardware.cpp.o
# [ 12%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/hardware/libgromacs_generated_device_management.cu.o
# [ 12%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/hardware/libgromacs_generated_device_management_common.cpp.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/listed_forces/libgromacs_generated_listed_forces_gpu_impl_gpu.cpp.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/listed_forces/libgromacs_generated_listed_forces_gpu_internal.cu.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/mdlib/libgromacs_generated_gpuforcereduction_impl.cpp.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/mdlib/libgromacs_generated_gpuforcereduction_impl_internal.cu.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/mdlib/libgromacs_generated_leapfrog_gpu.cpp.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/mdlib/libgromacs_generated_leapfrog_gpu_internal.cu.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/mdlib/libgromacs_generated_lincs_gpu.cpp.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/mdlib/libgromacs_generated_lincs_gpu_internal.cu.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/mdlib/libgromacs_generated_mdgraph_gpu_impl.cu.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/mdlib/libgromacs_generated_settle_gpu.cpp.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/mdlib/libgromacs_generated_settle_gpu_internal.cu.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/mdlib/libgromacs_generated_update_constrain_gpu_impl.cpp.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/mdlib/libgromacs_generated_update_constrain_gpu_internal.cu.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/mdtypes/libgromacs_generated_state_propagator_data_gpu_impl_gpu.cpp.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/nbnxm/cuda/libgromacs_generated_nbnxm_cuda.cu.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/nbnxm/cuda/libgromacs_generated_nbnxm_cuda_data_mgmt.cu.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/nbnxm/cuda/libgromacs_generated_nbnxm_cuda_kernel_F_noprune.cu.o
# [ 13%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/nbnxm/cuda/libgromacs_generated_nbnxm_cuda_kernel_F_prune.cu.o
# [ 15%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/nbnxm/cuda/libgromacs_generated_nbnxm_cuda_kernel_VF_noprune.cu.o
# [ 15%] Building NVCC (Device) object src/gromacs/CMakeFiles/libgromacs.dir/nbnxm/cuda/libgromacs_generated_nbnxm_cuda_kernel_VF_prune.cu.o

# %%
# Check that GROMACS works
# %%bash
source "/content/drive/MyDrive/gmx/gromacs/bin/GMXRC"
gmx -h
